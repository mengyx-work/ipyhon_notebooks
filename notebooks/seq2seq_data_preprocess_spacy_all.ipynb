# %%
import os, sys, json, time, re
import random, collections, cPickle
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import cPickle as pickle
import spacy
sys.path.append('/Users/matt.meng/dev/seq2seq_model/')
# %matplotlib inline

# %%
data_path = '/Users/matt.meng'
file_name = 'insights_article_data_title_only_20170719_20170728.json'
meta_data_file_name = 'meta_title_data.csv'
output_pickle_file = 'new_processed_titles_data.pkl'
delimiter = '\t\t'

# %%
def isEnglish(s):
    try:
        s.encode(encoding='utf-8').decode('ascii')
    except UnicodeDecodeError:
        return False
    else:
        return True
    
def convert_text_JSON_to_csv(data_path, csv_path, delimiter='\t'):
    start_time = time.time()
    batch_size = 2000
    raw_content = ""
    expected_keys = ['title', 'url', 'traffic', 'publisherId']
    with open(data_path, 'r') as raw_input:
        with open(csv_path, 'w') as raw_output:
            counter = 0
            raw_output.write(delimiter.join(expected_keys) + "\n")
            for line in raw_input:
                json_doc = json.loads(line)
                if not all([key in json_doc.keys() for key in expected_keys]):
                    continue
                elem_list = [json_doc['title'], json_doc['url'], json_doc['traffic'], json_doc['publisherId']]
                if not all([isEnglish(elem) for elem in elem_list]):
                    continue
                raw_content += delimiter.join(elem_list) + "\n"
                counter += 1
                if counter % batch_size == 0:
                    raw_output.write(raw_content)
                    raw_content = ""
                if counter % (20 * batch_size) == 0:
                    print 'finished processing {} rows using {:.2f} seconds'.format(counter, time.time() - start_time)
    print 'finished processing all the data using {:.2f} seconds'.format(time.time() - start_time)

# %%
convert_text_JSON_to_csv(os.path.join(data_path, file_name), os.path.join(data_path, meta_data_file_name), delimiter)
# Out:
# finished processing 40000 rows using 4.64 seconds
# finished processing 80000 rows using 8.99 seconds
# finished processing 120000 rows using 12.94 seconds
# finished processing 160000 rows using 18.03 seconds
# finished processing 200000 rows using 22.68 seconds
# finished processing 240000 rows using 25.94 seconds
# finished processing 280000 rows using 29.19 seconds
# finished processing 320000 rows using 32.48 seconds
# finished processing 360000 rows using 35.76 seconds
# finished processing 400000 rows using 38.99 seconds
# finished processing 440000 rows using 42.23 seconds
# finished processing 480000 rows using 45.47 seconds
# finished processing 520000 rows using 48.68 seconds
# finished processing 560000 rows using 52.18 seconds
# finished processing 600000 rows using 56.85 seconds
# finished processing 640000 rows using 61.46 seconds
# finished processing 680000 rows using 65.20 seconds
# finished processing all the data using 66.85 seconds

# %%
data = pd.read_csv(os.path.join(data_path, meta_data_file_name), index_col='url', delimiter=delimiter, encoding='utf-8')
# Out:
# /Users/matt.meng/.virtualenvs/kaggle/lib/python2.7/site-packages/ipykernel/__main__.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   if __name__ == '__main__':

# %%
print data.shape
data.head()
# Out:
# (698007, 3)
#                                                                                                 title  \
# url
# http://pix11.com/2017/07/17/iconic-lower-east-s...  Iconic Lower East Side Cup and Saucer diner cl...
# http://www.cbsnews.com/news/ulysha-renee-hall-f...  Ulysha Hall makes history as Dallas Police Dep...
# http://www.abante-tonite.com/student-lumaklak-n...      UP STUDENT LUMAKLAK NG ASIDO! - Abante Tonite
# http://www.jsonline.com/story/news/2017/06/17/p...  Paul Nehlen to challenge Paul Ryan after losin...
# http://www.msn.com/en-us/lifestyle/family-relat...  What Is It Like to Be in an Open Marriage? 1 W...
#
#                                                     traffic  publisherId
# url
# http://pix11.com/2017/07/17/iconic-lower-east-s...    240.0    1002700.0
# http://www.cbsnews.com/news/ulysha-renee-hall-f...    116.0    1038583.0
# http://www.abante-tonite.com/student-lumaklak-n...    384.0    1062055.0
# http://www.jsonline.com/story/news/2017/06/17/p...    352.0    1053378.0
# http://www.msn.com/en-us/lifestyle/family-relat...    219.0    1023406.0

# %%
url = 'https://www.cnet.com/news/pubg-playerunknown-brendan-greene-interview-july-2017/'
data.loc[url]
# Out:
# title          Finding PlayerUnknown, the my
# traffic                                 3895
# publisherId                      1.03858e+06
# Name: https://www.cnet.com/news/pubg-playerunknown-brendan-greene-interview-july-2017/, dtype: object

# %%
data.dropna(how='any', inplace=True)
data['publisherId'] = data['publisherId'].astype(int).astype(str)
valid_publisher_ids = ['1001082', '1023406', '1003264', '1040522', '782', '1006541',
                        '1168', '1038583', '1021516', '580', '1020689', '1031851', '1001264',
                        '1039208', '1054980', '1018671', '1031841', '1031842', '1031852',
                        '1008941', '1003764', '1068057', '1038711', '1002628', '1031853',
                        '1021578', '1043813', '1010748', '1040526', '1005092', '612',
                        '1003870', '1001156', '1012083', '1017946', '1041479', '1027016',
                        '1010488', '1017947', '1010497', '1038582', '1045821', '1020968',
                        '1037842', '1029984', '723', '196', '1030941']

filtered_data = data.loc[data['publisherId'].isin(valid_publisher_ids), :]
unique_filtered_data = filtered_data[~filtered_data.index.duplicated(keep='first')]
print unique_filtered_data.shape
# Out:
# (128155, 3)

# %%
print unique_filtered_data.shape
unique_filtered_data.head()
# Out:
# (128155, 3)
#                                                                                                 title  \
# url
# http://www.cbsnews.com/news/ulysha-renee-hall-f...  Ulysha Hall makes history as Dallas Police Dep...
# http://www.msn.com/en-us/lifestyle/family-relat...  What Is It Like to Be in an Open Marriage? 1 W...
# https://www.msn.com/en-us/foodanddrink/recipes/...  Add Excitement to Your Scrambled Eggs with One...
# http://www.msn.com/en-us/movies/celebrity/valer...  Valerian's Dane DeHaan Says His Love for New B...
# http://www.ajc.com/news/health-med-fit-science/...  Will low-calorie sugar substitutes, artificial...
#
#                                                     traffic publisherId
# url
# http://www.cbsnews.com/news/ulysha-renee-hall-f...    116.0     1038583
# http://www.msn.com/en-us/lifestyle/family-relat...    219.0     1023406
# https://www.msn.com/en-us/foodanddrink/recipes/...    114.0     1068057
# http://www.msn.com/en-us/movies/celebrity/valer...    113.0     1023406
# http://www.ajc.com/news/health-med-fit-science/...    384.0     1041479

# %%
nlp = spacy.load('en')

# %%
index = 40
title_content = data['title'][index].decode('ascii')
doc1 = nlp(title_content)
print 'the content: ', title_content
print '-------------'
for ent in doc1.ents:
    print ent, ent.label_
print '-------------'
for token in doc1:
    print token, token.pos_, token.tag_, token.lemma_, token.is_stop
# Out:
# the content:  Tulane's goal in Year 2 under Willie Fritz: 'We want to get in a bowl game'
# -------------
# Tulane ORG
# Year 2 DATE
# Willie Fritz PERSON
# -------------
# Tulane PROPN NNP tulane False
# 's PART POS 's False
# goal NOUN NN goal False
# in ADP IN in True
# Year PROPN NNP year False
# 2 NUM CD 2 False
# under ADP IN under True
# Willie PROPN NNP willie False
# Fritz PROPN NNP fritz False
# : PUNCT : : False
# ' PUNCT `` ' False
# We PRON PRP -PRON- True
# want VERB VBP want False
# to PART TO to True
# get VERB VB get True
# in ADP IN in True
# a DET DT a True
# bowl NOUN NN bowl False
# game NOUN NN game False
# ' PUNCT '' ' False

# %% [markdown]
# #### customize the processing functions

# %%
def basic_tokenizer(line, normalize_digits=True):
    line = line.replace("'s", '')
    line = re.sub(r"\'ve", " have ", line)
    line = re.sub(r"can't", "can not ", line)
    line = re.sub(r"n't", " not ", line)
    line = re.sub(r"I'm", "I am", line)
    line = re.sub(r" m ", " am ", line)
    line = re.sub(r"\'re", " are ", line)
    line = re.sub(r"\'d", " would ", line)
    line = re.sub(r"\'ll", " will ", line)
    line = re.sub(r"-", " ? ", line)
    #line = re.sub(r"!", " ! ", line)
    #line = re.sub(r":", " : ", line)
    line = re.sub('[\.,;\?"#%\'()*+/;<=>@\[\]^_{|}~\\\]', ' ', line)
    line = re.sub('[\n\t ]+', ' ', line)
    words = []
    _DIGIT_RE = re.compile(r"\d")
    for token in line.strip().lower().split():
        if not token:
            continue
        if normalize_digits:
            token = re.sub(_DIGIT_RE, b'#', token)
        words.append(token)
    return len(words), ' '.join(words)


def tokenize_title_column(data, processed_column_name, pageView_column_name='pageView', title_column_name='title'):
    data['title_word_counts'], data[processed_column_name] = zip(*data[title_column_name].map(basic_tokenizer))
    # sort by the title word counts and filter them
    sorted_data = data.sort_values(by=['title_word_counts', pageView_column_name], ascending=[True, False])
    index = (sorted_data['title_word_counts'] >= 5) & (sorted_data['title_word_counts'] <= 15)
    filtered_data = sorted_data.loc[index, :]
    print 'finish the tokenization...'
    return filtered_data


_PAD = b"_PAD"
_GO = b"_GO"
_EOS = b"_EOS"
_UNK = b"_UNK"
_START_VOCAB = [_PAD, _GO, _EOS, _UNK]

TOKEN_DICT = {}
REVERSE_TOKEN_DICT = {}
for i in xrange(len(_START_VOCAB)):
    TOKEN_DICT[_START_VOCAB[i]] = i
    REVERSE_TOKEN_DICT[i] = _START_VOCAB[i]


def create_vocab_dict(data, column_name, pageView_column_name='pageView', token_freq_threshold=5, UKN_frac_threshold=0.3):
    vocab_dict = {}
    all_titles = []
    selected_titles = []
    selected_title_urls = []
    selected_title_pageView = []
    for title, url, pageView in zip(data[column_name], data.index, data[pageView_column_name]):
        words = []
        for token in title.split(' '):
            words.append(token)
            if token not in vocab_dict:
                vocab_dict[token] = 0
            vocab_dict[token] += 1
        all_titles.append((words, url, pageView))
    print 'total {} tokens are identified...'.format(len(vocab_dict))

    token_dict, reverse_token_dict = TOKEN_DICT.copy(), REVERSE_TOKEN_DICT.copy()
    UKN_index = len(token_dict) - 1
    unique_counts = 0
    sorted_pairs = sorted(vocab_dict.items(), key=lambda x: x[1], reverse=True)
    for i, pair in enumerate(sorted_pairs):
        if pair[1] >= token_freq_threshold:
            unique_counts += 1
            token_dict[pair[0]] = i + 1 + UKN_index
            reverse_token_dict[(i + 1 + UKN_index)] = pair[0]
        else:
            token_dict[pair[0]] = UKN_index
    print 'total {} unique tokens are included in the token dictionary...'.format(unique_counts)

    for i in xrange(len(all_titles)):
        indexed_title = map(token_dict.get, all_titles[i][0])
        UKN_count = sum([elem == UKN_index for elem in indexed_title])
        if (1. * UKN_count / len(indexed_title)) < UKN_frac_threshold:
            selected_titles.append(indexed_title)
            selected_title_urls.append(all_titles[i][1])
            selected_title_pageView.append(all_titles[i][2])

    print 'total {} titles are included...'.format(len(selected_titles))
    return token_dict, reverse_token_dict, selected_titles, selected_title_urls, selected_title_pageView

# %%
title = 'those pointless upper-middle-class entitlements'
basic_tokenizer(title)
# Out:
# (6, 'those pointless upper middle class entitlements')

# %%
processed_column_name = 'processed_title'
pageView_column_name = 'traffic'
filtered_data = tokenize_title_column(unique_filtered_data, processed_column_name, pageView_column_name)
# Out:
# /Users/matt.meng/.virtualenvs/kaggle/lib/python2.7/site-packages/ipykernel/__main__.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# finish the tokenization...

# %%
print filtered_data.shape
filtered_data.head()
# Out:
# (119206, 5)
#                                                                                     title  \
# url
# http://www.msn.com/en-us/news/breakingnews/live...            Live Coverage from CBS News
# http://www.politico.com/story/2017/07/28/how-mc...    How McCain upended Obamacare repeal
# http://www.huffingtonpost.com/katie-hurley/ther...  There's Nothing Selfish About Suicide
# http://www.nbcnews.com/politics/white-house/can...      Can the president pardon himself?
# http://www.huffingtonpost.com/entry/why-im-a-ra...                       Why I'm A Racist
#
#                                                      traffic publisherId  \
# url
# http://www.msn.com/en-us/news/breakingnews/live...  348010.0     1023406
# http://www.politico.com/story/2017/07/28/how-mc...  187020.0         612
# http://www.huffingtonpost.com/katie-hurley/ther...  104351.0     1040522
# http://www.nbcnews.com/politics/white-house/can...   95782.0     1010748
# http://www.huffingtonpost.com/entry/why-im-a-ra...   81273.0     1040522
#
#                                                     title_word_counts  \
# url
# http://www.msn.com/en-us/news/breakingnews/live...                  5
# http://www.politico.com/story/2017/07/28/how-mc...                  5
# http://www.huffingtonpost.com/katie-hurley/ther...                  5
# http://www.nbcnews.com/politics/white-house/can...                  5
# http://www.huffingtonpost.com/entry/why-im-a-ra...                  5
#
#                                                                         processed_title
# url
# http://www.msn.com/en-us/news/breakingnews/live...          live coverage from cbs news
# http://www.politico.com/story/2017/07/28/how-mc...  how mccain upended obamacare repeal
# http://www.huffingtonpost.com/katie-hurley/ther...  there nothing selfish about suicide
# http://www.nbcnews.com/politics/white-house/can...     can the president pardon himself
# http://www.huffingtonpost.com/entry/why-im-a-ra...                    why i am a racist

# %%
#titles = filtered_data['processed_title'].tolist()

# %%
index = 15
title_content = filtered_data['processed_title'][index]
title_content = title_content.decode('ascii')
doc = nlp(title_content)
print title_content
print '-------------'
for token in doc:
    print token, token.pos_, token.tag_, token.lemma_, token.is_stop
print '-------------'
for token in doc:
    if (token.pos_ == u'NOUN' or token.pos_ == u'PROPN') and not token.is_stop:
        print token
print '-------------'
for ent in doc.ents:
    print ent, ent.label_
# Out:
# doctor who actor passes away
# -------------
# doctor NOUN NN doctor False
# who NOUN WP who True
# actor NOUN NN actor False
# passes VERB VBZ pass False
# away ADV RB away False
# -------------
# doctor
# actor
# -------------

# %%
stop_words = set(['msn', 'breitbart', 'news', 'commentary', 'coverage'])

def process_title_column(data, title_column_name, pageView_column_name):
    '''function to create the vocabulary dictionary and collect
    the titles according to the selection rules (include only the nourns.)
    '''
    all_titles, vocab_dict = [], {}
    count, start_time = 0, time.time()
    nlp = spacy.load('en')
    for title, url, pageView in zip(data[title_column_name], data.index, data[pageView_column_name]):
        words = []
        title_content = title.decode('ascii')
        doc = nlp(title_content)
        count += 1
        if count % 10000 == 0:
            print 'finish {} using {:.2f} seconds'.format(count, time.time() - start_time)
        if count == 50000:
            break
            
        for token in doc:
            word = token.lemma_.encode('ascii')
            if word in stop_words or '#' in word:
                continue
            if (token.pos_ == u'NOUN' or token.pos_ == u'PROPN') and not token.is_stop:
                if word not in words:
                    # the title is restricted to contain only only entities
                    # and exlude the duplicate words
                    words.append(word) 
                if word not in vocab_dict:
                    vocab_dict[word] = 0
                vocab_dict[word] += 1
        if len(words) > 0:
            all_titles.append((words, url, pageView))
    print 'total {} tokens are identified...'.format(len(vocab_dict))
    return all_titles, vocab_dict



_PAD = b"_PAD"
_GO = b"_GO"
_EOS = b"_EOS"
_UNK = b"_UNK"
_START_VOCAB = [_PAD, _GO, _EOS, _UNK]

TOKEN_DICT = {}
REVERSE_TOKEN_DICT = {}
for i in xrange(len(_START_VOCAB)):
    TOKEN_DICT[_START_VOCAB[i]] = i
    REVERSE_TOKEN_DICT[i] = _START_VOCAB[i]
    

def create_selected_vocab_dict(vocab_dict, UKN_index, token_freq_threshold):
    '''process the vocabulary dictionary and use `token_freq_threshold`
    to create a token dictionary
    '''
    token_dict, reverse_token_dict = TOKEN_DICT.copy(), REVERSE_TOKEN_DICT.copy()
    unique_counts = 0
    sorted_pairs = sorted(vocab_dict.items(), key=lambda x: x[1], reverse=True)
    for i, pair in enumerate(sorted_pairs):
        if pair[1] >= token_freq_threshold:
            unique_counts += 1
            token_dict[pair[0]] = i + 1 + UKN_index
            reverse_token_dict[(i + 1 + UKN_index)] = pair[0]
        else:
            token_dict[pair[0]] = UKN_index
    print 'total {} unique tokens are included in the token dictionary...'.format(unique_counts)
    return token_dict, reverse_token_dict


def process_title_with_token_dict(all_titles, token_dict, UKN_index, UKN_frac_threshold):
    selected_titles = []
    selected_title_urls = []
    selected_title_pageView = []
    for i in xrange(len(all_titles)):
        indexed_title = map(token_dict.get, all_titles[i][0])
        if len(indexed_title) == 0:
            continue
        UKN_count = sum([elem == UKN_index for elem in indexed_title])
        if (1. * UKN_count / len(indexed_title)) < UKN_frac_threshold:
            selected_titles.append(indexed_title)
            selected_title_urls.append(all_titles[i][1])
            selected_title_pageView.append(all_titles[i][2])

    print 'total {} titles are included...'.format(len(selected_titles))
    #return token_dict, reverse_token_dict, selected_titles, selected_title_urls, selected_title_pageView
    return {'url': selected_title_urls,
            'titles': selected_titles,
            'pageViw': selected_title_pageView,
            'token_dict': token_dict,
            'reverse_token_dict': reverse_token_dict}

# %%
UKN_index = len(TOKEN_DICT) - 1

# %%
all_titles, vocab_dict = process_title_column(filtered_data, 'processed_title', 'traffic')
# Out:
# finish 10000 using 10.08 seconds
# finish 20000 using 16.01 seconds
# finish 30000 using 21.87 seconds
# finish 40000 using 29.02 seconds
# finish 50000 using 36.54 seconds
# total 14623 tokens are identified...

# %%
print len(all_titles)
# Out:
# 49854

# %% [markdown]
# #### check the topK entities

# %%
sorted_pairs = sorted(vocab_dict.items(), key=lambda x: x[1], reverse=True)
for i in xrange(40):
    print sorted_pairs[i]
# Out:
# ('trump', 2612)
# ('man', 1641)
# ('woman', 1284)
# ('police', 1257)
# ('year', 828)
# ('horoscope', 766)
# ('death', 660)
# ('health', 650)
# ('house', 632)
# ('report', 586)
# ('home', 572)
# ('city', 531)
# ('state', 516)
# ('thing', 506)
# ('video', 504)
# ('photo', 497)
# ('crash', 480)
# ('world', 475)
# ('bill', 465)
# ('star', 461)
# ('car', 459)
# ('baby', 430)
# ('school', 422)
# ('russia', 419)
# ('love', 417)
# ('john', 408)
# ('child', 407)
# ('care', 407)
# ('time', 403)
# ('family', 399)
# ('park', 395)
# ('way', 388)
# ('people', 383)
# ('cancer', 383)
# ('session', 368)
# ('fire', 368)
# ('county', 366)
# ('life', 365)
# ('game', 363)
# ('mccain', 361)

# %% [markdown]
# #### creat the token dictionary

# %%
token_dict, reverse_token_dict = create_selected_vocab_dict(vocab_dict, UKN_index, token_freq_threshold=4)
# Out:
# total 6330 unique tokens are included in the token dictionary...

# %% [markdown]
# #### creat the content dictionary

# %%
processed_content = process_title_with_token_dict(all_titles, token_dict, UKN_index, UKN_frac_threshold=0.3)
# Out:
# total 44571 titles are included...

# %%
processed_content.keys()
content = processed_content.copy()

# %%
def print_content_by_index(content, index):
    reverse_token_dict = content['reverse_token_dict']
    print content['pageViw'][index]
    print content['url'][index]
    print map(reverse_token_dict.get, content['titles'][index])
    print '-----------------------'

# %%
for index in xrange(30 ,50):
    print_content_by_index(processed_content, index)
# Out:
# 15244.0
# http://www.huffingtonpost.com/entry/are-all-inclusive-resorts-safe_us_59722b30e4b0f1feb89b42fe
# ['resort']
# -----------------------
# 14655.0
# http://www.msn.com/en-us/news/politics/al-gore-?i-was-wrong?-on-trump/ar-BBEG7Ik
# ['politic', 'al', 'gore']
# -----------------------
# 14532.0
# http://www.msnbc.com/am-joy/watch/advice-to-trump-staffers-run-949699651614
# ['advice', 'staffer']
# -----------------------
# 14455.0
# http://www.businessinsider.com/13-chains-taking-over-america-2017-7
# ['chain', 'america']
# -----------------------
# 13134.0
# http://www.politico.com/story/2017/07/25/house-overwhelmingly-approves-russia-sanctions-240951
# ['house', 'russia', 'sanction']
# -----------------------
# 12752.0
# http://www.fox29.com/news/269835700-story
# ['company', 'employee', 'microchip', 'implant']
# -----------------------
# 12619.0
# http://dailymail.co.uk/news/article-4737052
# ['west', 'dog', 'diamond']
# -----------------------
# 12554.0
# http://www.msn.com/en-us/money/companies/what-happened-when-walmart-left/ar-BBEkIo1
# ['walmart']
# -----------------------
# 12072.0
# http://www.wsbtv.com/entertainment/best-bbq-festivals-around-georgia/563993022
# ['bbq', 'festival', 'georgia']
# -----------------------
# 11913.0
# http://www.9news.com/news/investigations/caregiver-savagely-beaten-to-death/458716067
# ['caregiver', 'death']
# -----------------------
# 11607.0
# http://dailymail.co.uk/news/article-4737860
# ['senate', 'sanction', 'bill']
# -----------------------
# 11529.0
# http://www.cnbc.com/2017/07/20/watch-oj-simpson-parole-hearing.html
# ['watch', 'simpson', 'parole']
# -----------------------
# 11117.0
# https://www.usatoday.com/videos/sports/mlb/2017/07/19/2017-mlb-trade-deadline-tracker/103821462/
# ['mlb', 'trade', 'deadline', 'tracker']
# -----------------------
# 10879.0
# http://dailymail.co.uk/news/article-4720086
# ['chris', '_UNK', 'concert', 'promoter']
# -----------------------
# 10482.0
# http://www.cnbc.com/video/3000639134
# ['alphabet', 'beat', 'line']
# -----------------------
# 10218.0
# https://www.usatoday.com/videos/sports/2017/07/23/jordan-spieth-wins-british-open/103940834/
# ['jordan', 'british']
# -----------------------
# 9966.0
# https://www.bloomberg.com/news/articles/2017-07-20/how-to-fix-social-security
# ['security']
# -----------------------
# 9816.0
# http://myfox8.com/2017/07/27/alamance-county-kidnapping-victim-located/
# ['alamance', 'county', 'victim']
# -----------------------
# 9392.0
# http://www.msn.com/en-us/sports/nba/mcgee-reportedly-unhappy-with-warriors/ar-BBEuKmF
# ['mcgee', 'warrior']
# -----------------------
# 9161.0
# http://www.msnbc.com/morning-joe/watch/inside-jeff-sessions-unending-nightmare-1011158595755
# ['jeff', 'session', 'nightmare']
# -----------------------

# %%
benchmark_index = 80
print_content_by_index(content, benchmark_index)
# Out:
# 5751.0
# http://www.dailymail.co.uk/femail/article-4714974/Celebrity-Beach-Vacation-Beauty-Looks.html
# ['celebrity', 'beauty']
# -----------------------

# %%
print benchmark_index
# Out:
# 70

# %%
threshold = 0.5
benchmark_title_len = len(content['titles'][benchmark_index])
for index in xrange(len(content['titles'])):
    common_counts = 0
    for word_index in content['titles'][benchmark_index]:
        if word_index in content['titles'][index]:
            common_counts += 1
    max_len = max(len(content['titles'][index]), benchmark_title_len)
    if 1.*common_counts/max_len >= threshold:
        print_content_by_index(content, index)
# Out:
# 5751.0
# http://www.dailymail.co.uk/femail/article-4714974/Celebrity-Beach-Vacation-Beauty-Looks.html
# ['celebrity', 'beauty']
# -----------------------
# 5429.0
# http://dailymail.co.uk/news/article-4714974
# ['celebrity', 'beauty']
# -----------------------
# 1150.0
# http://dailym.ai/2vovLaU
# ['celebrity', 'beauty']
# -----------------------
# 875.0
# http://www.huffingtonpost.com/2013/10/16/gorgeous-celebrities-over-60_n_4109868.html
# ['celebrity']
# -----------------------
# 127.0
# http://metro.co.uk/2013/04/06/lindsay-lohan-jennifer-aniston-and-mel-bs-boobs-real-or-fake-3564290/
# ['celebrity', 'boob']
# -----------------------
# 63.0
# http://www.wsbtv.com/news/national/hot-topics/weird-first-tweets-of-celebrities/560204554
# ['tweet', 'celebrity']
# -----------------------
# 54.0
# http://www.independent.co.uk/life-style/fashion/15-best-online-beauty-retailers-beauty-pie-cult-beauty-space-nk-birchbox-9158731.html
# ['beauty', 'retailer']
# -----------------------
# 3011.0
# http://www.huffingtonpost.com/vanessa-cunningham/dangerous-beauty-products_b_4168587.html
# ['beauty', 'ingredient']
# -----------------------
# 1060.0
# http://www.msn.com/en-us/health/healthtrending/celebrities-slacklining-to-lift-their-butts/ar-BBEfe15
# ['celebrity', 'butt']
# -----------------------
# 877.0
# http://www.huffingtonpost.com/2011/07/13/dreams-about-celebrities_n_871854.html
# ['celebrity', 'meaning']
# -----------------------
# 511.0
# https://www.usatoday.com/story/life/people/2016/06/02/celebrities-who-have-died-addiction/85314450/
# ['celebrity', 'addiction']
# -----------------------
# 453.0
# http://www.businessinsider.com/10-celebrities-who-came-from-nothing-2014-4
# ['celebrity']
# -----------------------
# 168.0
# http://www.dailymail.co.uk/femail/article-3176212/Can-tell-apart-Keira-Knightley-Natalie-Portman-Katy-Perry-Zooey-Deschanel-uncanny-celebrity-look-likes-revealed.html
# ['celebrity']
# -----------------------
# 55.0
# http://www.usatoday.com/story/life/people/2016/06/02/celebrities-who-have-died-addiction/85314450/
# ['celebrity', 'addiction']
# -----------------------
# 18706.0
# http://www.breitbart.com/big-hollywood/2017/07/18/5-creepiest-celebrity-pitches-for-obamacare/
# ['celebrity', 'advertisement']
# -----------------------
# 2230.0
# http://atlantablackstar.com/2016/12/12/38-black-celebrities-who-died-in-2016/
# ['celebrity']
# -----------------------
# 839.0
# http://atlantablackstar.com/2016/12/12/38-black-celebrities-who-died-in-2016/2/
# ['celebrity']
# -----------------------
# 828.0
# http://a.msn.com/09/en-us/BBEjgXR
# ['celebrity']
# -----------------------
# 598.0
# http://atlantablackstar.com/2016/12/12/38-black-celebrities-who-died-in-2016/3/
# ['celebrity']
# -----------------------
# 528.0
# http://atlantablackstar.com/2016/12/12/38-black-celebrities-who-died-in-2016/4/
# ['celebrity']
# -----------------------
# 506.0
# http://atlantablackstar.com/2016/12/12/38-black-celebrities-who-died-in-2016/5/
# ['celebrity']
# -----------------------
# 444.0
# http://www.businessinsider.com/richest-celebrities-in-the-world-2016-8
# ['celebrity', 'world']
# -----------------------
# 363.0
# http://atlantablackstar.com/2016/12/12/38-black-celebrities-who-died-in-2016/6/
# ['celebrity']
# -----------------------
# 344.0
# http://atlantablackstar.com/2016/12/12/38-black-celebrities-who-died-in-2016/7/
# ['celebrity']
# -----------------------
# 279.0
# http://atlantablackstar.com/2016/12/12/38-black-celebrities-who-died-in-2016/8/
# ['celebrity']
# -----------------------
# 217.0
# http://atlantablackstar.com/2016/12/12/38-black-celebrities-who-died-in-2016/9/
# ['celebrity']
# -----------------------
# 202.0
# http://atlantablackstar.com/2016/12/12/38-black-celebrities-who-died-in-2016/10/
# ['celebrity']
# -----------------------
# 142.0
# http://atlantablackstar.com/2016/12/12/38-black-celebrities-who-died-in-2016/11/
# ['celebrity']
# -----------------------
# 129.0
# http://atlantablackstar.com/2016/12/12/38-black-celebrities-who-died-in-2016/12/
# ['celebrity']
# -----------------------
# 128.0
# http://atlantablackstar.com/2016/12/12/38-black-celebrities-who-died-in-2016/18/
# ['celebrity']
# -----------------------
# 125.0
# http://atlantablackstar.com/2016/12/12/38-black-celebrities-who-died-in-2016/13/
# ['celebrity']
# -----------------------
# 124.0
# http://atlantablackstar.com/2016/12/12/38-black-celebrities-who-died-in-2016/14/
# ['celebrity']
# -----------------------
# 119.0
# http://atlantablackstar.com/2016/12/12/38-black-celebrities-who-died-in-2016/15/
# ['celebrity']
# -----------------------
# 65.0
# http://atlantablackstar.com/2016/12/12/38-black-celebrities-who-died-in-2016/16/
# ['celebrity']
# -----------------------
# 65.0
# http://atlantablackstar.com/2016/12/12/38-black-celebrities-who-died-in-2016/17/
# ['celebrity']
# -----------------------
# 64.0
# http://atlantablackstar.com/2016/12/12/38-black-celebrities-who-died-in-2016/19/
# ['celebrity']
# -----------------------
# 10913.0
# http://atlantablackstar.com/2014/02/03/8-celebrity-co-parents-you-may-not-know/5/
# ['celebrity', 'parent']
# -----------------------
# 10562.0
# http://atlantablackstar.com/2014/02/03/8-celebrity-co-parents-you-may-not-know/6/
# ['celebrity', 'parent']
# -----------------------
# 10268.0
# http://atlantablackstar.com/2014/02/03/8-celebrity-co-parents-you-may-not-know/7/
# ['celebrity', 'parent']
# -----------------------
# 9431.0
# http://atlantablackstar.com/2014/02/03/8-celebrity-co-parents-you-may-not-know/8/
# ['celebrity', 'parent']
# -----------------------
# 6510.0
# http://atlantablackstar.com/2014/10/13/8-black-celebrities-who-denied-being-african-american/5/
# ['celebrity']
# -----------------------
# 6101.0
# http://atlantablackstar.com/2014/10/13/8-black-celebrities-who-denied-being-african-american/6/
# ['celebrity']
# -----------------------
# 5750.0
# http://atlantablackstar.com/2014/10/13/8-black-celebrities-who-denied-being-african-american/7/
# ['celebrity']
# -----------------------
# 5394.0
# http://atlantablackstar.com/2014/10/13/8-black-celebrities-who-denied-being-african-american/8/
# ['celebrity']
# -----------------------
# 1514.0
# http://www.huffingtonpost.com/2012/06/20/full-frontal-nudity-celebrities-bared-it-all_n_1613527.html
# ['nudity', 'celebrity']
# -----------------------
# 1465.0
# http://atlantablackstar.com/2014/02/03/8-celebrity-co-parents-may-know/
# ['celebrity', 'parent']
# -----------------------
# 437.0
# http://www.nydailynews.com/entertainment/gossip/celebrities-hiv-positive-aids-article-1.2436964
# ['celebrity', 'aid']
# -----------------------
# 162.0
# http://www.businessinsider.com/celebrities-who-dont-drink-2017-2
# ['celebrity', 'alcohol']
# -----------------------
# 129.0
# http://www.huffingtonpost.com/entry/8-beauty-tricks-we-learned-from-the-french_us_5963d85ae4b09be68c0054a4
# ['beauty', 'trick']
# -----------------------
# 13103.0
# http://dailymail.co.uk/news/article-4603938
# ['celebrity', 'couple']
# -----------------------
# 5883.0
# http://www.dailymail.co.uk/tvshowbiz/article-4603938/The-celebrity-couples-wish-together.html
# ['celebrity', 'couple']
# -----------------------
# 2669.0
# http://dailym.ai/2v8nJlv
# ['celebrity', 'couple']
# -----------------------
# 1525.0
# http://www.dailymail.co.uk/tvshowbiz/article-4735666/Celebrity-Big-Brother-2017-know-far.html
# ['celebrity', 'brother']
# -----------------------
# 550.0
# http://www.huffingtonpost.com/entry/fabulously-me-the-beauty-in-being-a-black-sheep_us_596b0d97e4b022bb9372b25b
# ['beauty', 'sheep']
# -----------------------
# 94.0
# http://dailymail.co.uk/news/article-4735666
# ['celebrity', 'brother']
# -----------------------

# %% [markdown]
# #### check the titles by keyword

# %%
processed_content['titles'][30]
# Out:
# [931]

# %%
def search_title_by_keyword(key_word, content, token_dict, reverse_token_dict):
    count = 0
    token_index = token_dict[key_word]
    for index in xrange(len(processed_content['titles'])):
        if token_index in content['titles'][index]:
            count += 1
            print_content_by_index(content, index)
    print 'found total {} relevant titles'.format(count)

# %%
search_title_by_keyword('transgender', content, token_dict, reverse_token_dict)
# Out:
# 8910.0
# https://a.msn.com/r/2/AAoSqjT?m=en-us
# ['opinion', 'trump', 'transgender', 'patriot']
# -----------------------
# 5835.0
# http://www.huffingtonpost.com/brynn-tannehill/the-truth-about-transgend_b_8564834.html
# ['truth', 'transgender', 'suicide']
# -----------------------
# 1767.0
# https://www.usatoday.com/story/news/2017/07/26/transgender-troops-not-under-trump/511726001/
# ['transgender', 'troop', 'trump']
# -----------------------
# 307.0
# http://www.nydailynews.com/news/national/transgender-navy-seal-article-1.1362490
# ['transgender', 'navy', 'seal']
# -----------------------
# 181.0
# http://www.nbcnews.com/feature/nbc-out/pakistan-issues-landmark-transgender-passport-n778076
# ['issue', 'transgender', 'passport']
# -----------------------
# 159.0
# https://www.usatoday.com/story/news/politics/2013/07/23/transsexuals-military-struggle-acceptance/2513153/
# ['transgender', 'troop', 'silence']
# -----------------------
# 66.0
# http://www.huffingtonpost.com/joanne-herman/lgbt-rights-mental-illnes_b_605595.html
# ['illness', 'transgender', 'people']
# -----------------------
# 14431.0
# https://www.usatoday.com/story/news/politics/2017/07/26/trump-no-transgender-individuals-military/511858001/
# ['trump', 'transgender', 'individual']
# -----------------------
# 3519.0
# http://dailymail.co.uk/news/article-4735198
# ['parent', 'transgender', 'daughter']
# -----------------------
# 1553.0
# https://www.usatoday.com/videos/news/nation/2017/07/26/trump-ban-transgender-military/104029362/
# ['trump', 'transgender']
# -----------------------
# 1252.0
# http://www.dailymail.co.uk/femail/article-3325209/Transgender-woman-reveals-s-rejected-straight-men-male-parts-despite-chatted-time.html
# ['transgender', 'woman', 'man']
# -----------------------
# 1052.0
# http://dailym.ai/2vao8bd
# ['parent', 'transgender', 'daughter']
# -----------------------
# 829.0
# https://media.gannett-cdn.com/29906170001/29906170001_5522642732001_5522638510001.mp4
# ['trump', 'transgender']
# -----------------------
# 599.0
# http://www.dailymail.co.uk/femail/article-4735198/Christian-parents-support-transgender-daughter.html
# ['parent', 'transgender', 'daughter']
# -----------------------
# 511.0
# http://www.nbcwashington.com/news/local/Man-Convicted-of-Murdering-Transgender-Woman-436586043.html
# ['man', 'transgender', 'woman']
# -----------------------
# 275.0
# http://www.cbsnews.com/videos/white-house-defends-transgender-military-ban/
# ['house', 'transgender', 'ban']
# -----------------------
# 240.0
# https://www.usatoday.com/story/news/nation-now/2015/04/27/transgender-gender-identity-bruce-jenner-glaad/26451715/
# ['question', 'transgender']
# -----------------------
# 138.0
# http://www.cleveland.com/metro/index.ssf/2015/11/vas_first_transgender_clinic_o.html
# ['transgender', 'clinic', 'cleveland']
# -----------------------
# 107.0
# http://www.cbsnews.com/videos/trump-tweets-directive-banning-transgender-troops/
# ['trump', 'tweet', '_UNK', 'transgender', 'troop']
# -----------------------
# 106.0
# http://www.nbcwashington.com/news/national-international/Factcheck-Trump-and-Transgender-Service-Members-436829053.html
# ['_UNK', 'trump', 'transgender', 'service', 'member']
# -----------------------
# 66.0
# https://media.gannett-cdn.com/29906170001/29906170001_5522642426001_5522638510001.mp4
# ['trump', 'transgender']
# -----------------------
# 31942.0
# http://www.nbcwashington.com/news/national-international/Trump-Tweets-Trans-People-Will-Not-Be-Allowed-Into-Military-436723953.html
# ['trump', 'transgender', 'people']
# -----------------------
# 12210.0
# https://a.msn.com/r/2/AAoSD1a?m=en-us
# ['transgender', 'troop', 'ban']
# -----------------------
# 12189.0
# http://www.msn.com/en-us/news/us/minnesota-department-of-education-approves-transgender-toolkit/ar-AAoLsMy
# ['minnesota', 'department', 'education', 'transgender', 'toolkit']
# -----------------------
# 11657.0
# https://www.usatoday.com/videos/news/politics/2017/07/26/military-no-longer-accept-transgender-troops/104022050/
# ['military', 'transgender', 'troop']
# -----------------------
# 8158.0
# http://www.nbcnews.com/feature/nbc-out/minnesota-department-education-approves-transgender-toolkit-n785246
# ['minnesota', 'department', 'education', 'transgender', 'toolkit']
# -----------------------
# 5555.0
# http://www.wpxi.com/news/trending-now/whats-the-difference-between-transgender-and-transsexual/572211603
# ['difference', 'transgender']
# -----------------------
# 4244.0
# https://www.usatoday.com/story/opinion/2017/07/26/trumps-transparent-transgender-trick-ej-montini-column/512852001/
# ['trump', 'transgender', 'twitter', 'trick', '_UNK']
# -----------------------
# 3328.0
# http://www.huffingtonpost.com/mitch-kellaway/8-myths-about-transgender-mens-genital-reconstructions_b_4510196.html
# ['myth', 'transgender', 'man', 'reconstruction']
# -----------------------
# 3202.0
# http://www.10tv.com/article/local-transgender-veterans-angry-over-presidents-tweets
# ['transgender', 'veteran', 'president', 'tweet']
# -----------------------
# 2110.0
# http://www.huffingtonpost.com/entry/transgender-troops-we-will-not-go-back_us_5978d8e1e4b0c6616f7ce718
# ['transgender', 'troop']
# -----------------------
# 1625.0
# http://www.nj.com/politics/index.ssf/2017/07/trump_to_bar_transgender_individuals_from_military.html#incart_river_home
# ['trump', 'transgender', 'individual']
# -----------------------
# 1484.0
# http://www.chicagotribune.com/news/local/breaking/ct-transgender-military-chicago-met-20170726-story.html
# ['transgender', 'veteran', 'issue', 'trump', 'tweet']
# -----------------------
# 1210.0
# http://www.cbsnews.com/videos/transgender-service-members-react-to-trumps-ban/
# ['transgender', 'service', 'member', 'ban']
# -----------------------
# 1161.0
# http://www.huffingtonpost.com/janet-mock/transgender-coming-out_b_1146414.html
# ['boyfriend', 'transgender']
# -----------------------
# 904.0
# https://media.gannett-cdn.com/29906170001/29906170001_5522436428001_5522419096001.mp4
# ['military', 'transgender', 'troop']
# -----------------------
# 700.0
# http://www.al.com/news/mobile/index.ssf/2017/07/roy_moore_applauds_trumps_tran.html#incart_river_home
# ['roy', 'moore', 'trump', 'transgender', 'military', 'ban']
# -----------------------
# 578.0
# https://www.usatoday.com/story/news/politics/2017/07/28/fact-check-trump-and-transgender-service-members/520042001/
# ['fact', 'check', 'trump', 'transgender', 'service', 'member']
# -----------------------
# 552.0
# https://a.msn.com/r/2/AAoLsMy?m=en-us
# ['minnesota', 'department', 'education', 'transgender', 'toolkit']
# -----------------------
# 505.0
# https://apnews.com/80db66ddc50c472f95e65edc0c104e83
# ['duckworth', 'transgender', 'ban']
# -----------------------
# 439.0
# http://www.al.com/news/mobile/index.ssf/2017/07/roy_moore_applauds_trumps_tran.html
# ['roy', 'moore', 'trump', 'transgender', 'military', 'ban']
# -----------------------
# 358.0
# http://www.politico.com/story/2017/06/30/pentagon-delays-lifting-transgender-ban-240163
# ['pentagon', 'delay', '_UNK', 'transgender', 'troop', 'ban']
# -----------------------
# 305.0
# http://www.msnbc.com/rachel-maddow-show/trump-announcement-transgender-troops-surprises-pentagon
# ['trump', 'announcement', 'transgender', 'troop', 'surprise']
# -----------------------
# 299.0
# http://www.nbcwashington.com/news/national-international/Transgender-Service-Members-Accuse-Trump-of-Discrimination-436817703.html
# ['transgender', 'service', 'member', 'trump', 'discrimination']
# -----------------------
# 295.0
# https://www.usatoday.com/videos/news/politics/2017/07/27/canada-trolls-trump-over-transgender-military-ban/104038728/
# ['canada', 'trump', 'transgender', 'ban']
# -----------------------
# 291.0
# https://www.usatoday.com/videos/news/politics/2017/07/26/senate-dems-hit-health-vote-transgender-ban/104014756/
# ['senate', 'dem', 'health', 'vote', 'transgender', 'ban']
# -----------------------
# 284.0
# https://www.msn.com/en-us/news/us/minnesota-department-of-education-approves-transgender-toolkit/ar-AAoLsMy
# ['minnesota', 'department', 'education', 'transgender', 'toolkit']
# -----------------------
# 268.0
# http://www.businessinsider.com/the-most-transgender-inclusive-companies-2015-7
# ['transgender', 'company', 'america']
# -----------------------
# 240.0
# http://www.usatoday.com/videos/news/politics/2017/07/27/trump-says-military-no-longer-accept-transgender-troops/104022050/
# ['military', 'transgender', 'troop']
# -----------------------
# 232.0
# https://media.gannett-cdn.com/29906170001/29906170001_5522435726001_5522419096001.mp4
# ['military', 'transgender', 'troop']
# -----------------------
# 229.0
# http://bigstory.ap.org/urn:publicid:ap.org:80db66ddc50c472f95e65edc0c104e83
# ['duckworth', 'transgender', 'ban']
# -----------------------
# 206.0
# http://www.politico.com/story/2015/06/obama-lgbt-transgender-military-serving-ban-119373
# ['obama', 'lgbt', 'test', 'transgender', 'military', 'ban']
# -----------------------
# 204.0
# https://media.gannett-cdn.com/29906170001/29906170001_5522436253001_5522419096001.mp4
# ['military', 'transgender', 'troop']
# -----------------------
# 182.0
# http://www.nj.com/politics/index.ssf/2017/07/trump_to_bar_transgender_individuals_from_military.html#incart_river_index
# ['trump', 'transgender', 'individual']
# -----------------------
# 166.0
# http://www.nj.com/politics/index.ssf/2017/07/trump_to_bar_transgender_individuals_from_military.html#comments
# ['trump', 'transgender', 'individual']
# -----------------------
# 139.0
# http://www.usatoday.com/videos/news/nation/2017/07/26/wh-transgender-ban-best-military/104023552/
# ['wh', 'transgender', 'ban']
# -----------------------
# 128.0
# http://www.nbcnews.com/feature/nbc-out/canadian-lawmakers-pass-bill-extending-transgender-protections-n773421
# ['lawmaker', 'bill', 'transgender', 'protection']
# -----------------------
# 111.0
# https://www.usatoday.com/videos/news/nation/2017/07/26/wh-transgender-ban-best-military/104023552/
# ['wh', 'transgender', 'ban']
# -----------------------
# 102.0
# http://www.wsbtv.com/news/19-attorneys-general-seek-military-transgender-protections/574648169
# ['attorney', 'transgender', 'protection']
# -----------------------
# 85.0
# http://www.nj.com/politics/index.ssf/2017/07/trump_to_bar_transgender_individuals_from_military.html
# ['trump', 'transgender', 'individual']
# -----------------------
# 77.0
# http://www.usatoday.com/videos/news/politics/2017/07/26/senate-dems-hit-health-vote-transgender-ban/104014756/
# ['senate', 'dem', 'health', 'vote', 'transgender', 'ban']
# -----------------------
# 71.0
# http://www.huffingtonpost.com/entry/portrait-series-celebrates-diversity-in-transgender_us_5967e0a5e4b09e26b6d76693
# ['portrait', 'series', 'diversity', 'transgender', 'community']
# -----------------------
# 70.0
# https://www.usatoday.com/story/news/nation/2015/08/12/transgender-troops-treatment/31537791/
# ['cost', 'transgender', 'troop']
# -----------------------
# 69.0
# http://www.breitbart.com/big-government/2016/04/22/pro-family-group-launches-boycotttarget/
# ['group', 'launch', 'transgender', 'bathroom', 'policy']
# -----------------------
# 68.0
# https://www.usatoday.com/story/opinion/2016/02/28/gay-rights-trans-rights-south-dakota-bathroom-legislation-column/80710176/
# ['gay', 'transgender', 'movement', 'divorce', 'column']
# -----------------------
# 63.0
# http://bigstory.ap.org/80db66ddc50c472f95e65edc0c104e83
# ['duckworth', 'transgender', 'ban']
# -----------------------
# 59.0
# http://www.msnbc.com/thomas-roberts/watch/vet-hopes-to-end-transgender-military-ban-459966531894
# ['vet', 'transgender', 'military', 'ban']
# -----------------------
# 123613.0
# http://www.huffingtonpost.com/entry/trump-transgender-military-service-ban-republican-opposition_us_5978bbb4e4b0e201d57a65b4
# ['republican', 'trump', 'transgender', 'soldier']
# -----------------------
# 38036.0
# http://dailymail.co.uk/news/article-4732984
# ['caitlyn', 'jenner', 'trump', 'transgender', 'ban']
# -----------------------
# 28208.0
# https://www.usatoday.com/story/opinion/2017/07/26/trump-trans-ban-prioritizes-national-security-joseph-murray-column/513373001/
# ['trump', 'military', 'transgender', 'ban']
# -----------------------
# 17566.0
# http://www.cbsnews.com/news/trump-announces-ban-on-transgender-service-members-in-military-twitter/
# ['trump', 'ban', 'transgender', 'service', 'member']
# -----------------------
# 10494.0
# http://www.dailymail.co.uk/femail/article-3509357/Parts-melt-world-pain-Transgender-woman-shares-graphic-account-really-feels-like-undergo-gender-reassignment-surgery.html
# ['transgender', 'woman', 'detail', '_UNK']
# -----------------------
# 9328.0
# http://www.ajc.com/news/national/what-the-difference-between-transgender-and-transsexual/HDBZDYlss2DpZPqjl4z1RL/
# ['difference', 'transgender']
# -----------------------
# 7681.0
# http://dailymail.co.uk/news/article-4735932
# ['jame', 'trump', 'ban', 'transgender', 'soldier']
# -----------------------
# 6965.0
# http://mapi.huffpost.com/us/entry/us_5978bbb4e4b0e201d57a65b4
# ['republican', 'trump', 'transgender', 'soldier']
# -----------------------
# 6836.0
# http://a.msn.com/09/en-us/AAoNOyu
# ['transgender', 'boxer', 'fight', 'acceptance']
# -----------------------
# 6196.0
# http://www.msn.com/en-us/news/politics/transgender-candidate-takes-on-culture-warrior-in-virginia/ar-AAoJ5Hr
# ['transgender', 'candidate', 'culture', 'warrior', 'virginia']
# -----------------------
# 6069.0
# http://www.msnbc.com/all-in/watch/duckworth-trump-actions-on-transgender-ban-sickening-1010821187791
# ['duckworth', 'trump', 'action', 'transgender', 'ban']
# -----------------------
# 5769.0
# https://a.msn.com/r/2/AAoSSUr?m=en-us
# ['protester', 'trump', 'ban', 'transgender', 'troop']
# -----------------------
# 4957.0
# http://www.nydailynews.com/news/national/transgender-navy-seal-slams-trump-banning-servicemembers-article-1.3358836
# ['transgender', 'navy', 'seal', 'trump', '_UNK']
# -----------------------
# 4452.0
# http://bigstory.ap.org/43d5866df5bb4a098edf7f496ae968d5
# ['trump', 'transgender', 'individual', 'force']
# -----------------------
# 4321.0
# http://www.msn.com/en-us/news/politics/why-the-transgender-troop-ban-may-backfire-politically/ar-AAoSD1a
# ['transgender', 'troop', 'ban']
# -----------------------
# 3718.0
# http://www.dailymail.co.uk/news/article-4735932/James-Corden-slams-Trump-s-ban-transgender-soldiers.html
# ['jame', 'trump', 'ban', 'transgender', 'soldier']
# -----------------------
# 3465.0
# http://www.cbsnews.com/videos/trump-reimposes-military-ban-on-transgender-service-members/
# ['trump', '_UNK', 'ban', 'transgender', 'service', 'member']
# -----------------------
# 3356.0
# http://www.msn.com/en-us/news/politics/border-wall-tied-to-trump-transgender-ban-report/ar-AAoSxVS
# ['border', 'wall', 'transgender', 'ban', 'report']
# -----------------------
# 3347.0
# http://www.independent.co.uk/voices/john-barrowman-comicon-jodie-whittaker-dr-who-sexism-transgender-a7854946.html
# ['defense', 'john', 'barrowman', 'transgender', '_UNK', 'costume']
# -----------------------
# 3156.0
# http://www.nydailynews.com/entertainment/caitlyn-jenner-slams-trump-transgender-military-ban-article-1.3361061
# ['caitlyn', 'jenner', 'trump', 'transgender', 'military', 'ban']
# -----------------------
# 2937.0
# http://www.nbcnews.com/feature/nbc-out/transgender-candidate-takes-culture-warrior-virginia-n785891
# ['transgender', 'candidate', 'culture', 'warrior', 'virginia']
# -----------------------
# 2923.0
# https://www.usatoday.com/story/news/nation/2015/08/16/transgender-individuals-face-high-rates--suicide-attempts/31626633/
# ['transgender', 'people', 'risk', 'suicide']
# -----------------------
# 2102.0
# http://www.cbsnews.com/videos/did-a-spending-debate-spark-transgender-military-ban/
# ['spending', 'debate', 'spark', 'transgender', 'ban']
# -----------------------
# 2029.0
# http://www.nbcnews.com/feature/nbc-out/advocacy-groups-urge-states-protect-transgender-students-n784171
# ['_UNK', 'group', 'state', 'transgender', 'student']
# -----------------------
# 1948.0
# http://www.msn.com/en-us/news/us/transgender-womans-photo-with-texas-governor-goes-viral/ar-AAosyoY
# ['transgender', 'woman', 'photo', 'governor']
# -----------------------
# 1863.0
# http://www.9news.com/mobile/article/news/military/local-transgender-military-members-react-to-trumps-ban/73-459772628
# ['transgender', 'military', 'member', 'ban']
# -----------------------
# 1757.0
# https://a.msn.com/r/2/AAosyoY?m=en-us
# ['transgender', 'woman', 'photo', 'governor']
# -----------------------
# 1640.0
# https://www.usatoday.com/story/opinion/2017/07/27/transgender-military-ban-trump-again-out-step-world-david-andelman-column/514127001/
# ['transgender', 'ban', 'trump']
# -----------------------
# 1637.0
# http://www.9news.com/news/military/local-transgender-military-members-react-to-trumps-ban/459772628
# ['transgender', 'military', 'member', 'ban']
# -----------------------
# 1540.0
# http://dailym.ai/2u1R2VX
# ['jame', 'trump', 'ban', 'transgender', 'soldier']
# -----------------------
# 1216.0
# http://www.nbcnews.com/feature/nbc-out/first-openly-transgender-service-member-promoted-n648366
# ['transgender', 'service', 'member']
# -----------------------
# 1075.0
# http://www.dailymail.co.uk/femail/article-3354547/We-not-objects-Transgender-porn-stars-discrimination-face-working-adult-film-industry-claim-people-just-fetish.html
# ['transgender', 'porn', 'star', 'discrimination']
# -----------------------
# 954.0
# http://www.dailymail.co.uk/femail/article-3451684/I-guess-pansexual-Transgender-teen-Jazz-Jennings-reveals-attracted-boys-girls-admits-won-t-know-true-sexuality-falls-love.html
# ['transgender', 'teen', 'jazz', 'jenning']
# -----------------------
# 929.0
# https://www.usatoday.com/story/news/2017/07/26/joni-ernst-breaks-trump-transgender-military-ban/512830001/
# ['_UNK', 'trump', 'transgender', 'ban']
# -----------------------
# 909.0
# http://www.wpxi.com/news/top-stories/trump-to-bar-transgender-individuals-from-armed-forces/572007262
# ['trump', 'transgender', 'individual', 'force']
# -----------------------
# 852.0
# http://www.cbsnews.com/videos/lawmakers-clash-over-transgender-bathroom-bill-in-texas/
# ['lawmaker', 'transgender', 'bathroom', 'bill']
# -----------------------
# 826.0
# https://a.msn.com/r/2/AAoJ5Hr?m=en-us
# ['transgender', 'candidate', 'culture', 'warrior', 'virginia']
# -----------------------
# 755.0
# http://www.wthr.com/article/hoosiers-react-to-presidents-transgender-military-service-tweet
# ['_UNK', 'president', 'transgender', 'service', 'tweet']
# -----------------------
# 656.0
# http://www.latimes.com/opinion/readersreact/la-le-0729-tuesday-military-transgender-ban-20140729-story,amp.html
# ['con', 'transgender', 'ban']
# -----------------------
# 604.0
# http://www.nola.com/military/index.ssf/2017/07/trump_to_bar_transgender_indiv.html#incart_2box
# ['trump', 'transgender', 'individual', 'force']
# -----------------------
# 563.0
# http://www.usatoday.com/story/news/nation/2015/08/16/transgender-individuals-face-high-rates--suicide-attempts/31626633/
# ['transgender', 'people', 'risk', 'suicide']
# -----------------------
# 534.0
# http://www.nydailynews.com/news/politics/trump-announces-transgender-military-service-ban-twitter-article-1.3357685
# ['trump', 'transgender', 'service', 'ban', 'twitter']
# -----------------------
# 395.0
# http://www.latimes.com/opinion/readersreact/la-le-0729-tuesday-military-transgender-ban-20140729-story.html
# ['con', 'transgender', 'ban']
# -----------------------
# 385.0
# http://www.cbsnews.com/news/military-chiefs-seek-delay-in-allowing-transgender-enlistment/
# ['chief', 'delay', 'transgender', '_UNK']
# -----------------------
# 346.0
# http://www.nola.com/military/index.ssf/2017/07/trump_to_bar_transgender_indiv.html#incart_river_home_pop
# ['trump', 'transgender', 'individual', 'force']
# -----------------------
# 344.0
# https://www.usatoday.com/story/news/2017/07/27/what-did-trump-mean-his-transgender-tweet/515704001/
# ['trump', 'mean', 'transgender', 'tweet']
# -----------------------
# 344.0
# http://www.nbcwashington.com/news/politics/Trump-Transgender-Ban-Nod-to-Christian-Conservatives-Analysis-436906453.html
# ['trump', 'transgender', 'ban', 'nod', 'conservative', 'analysis']
# -----------------------
# 308.0
# http://www.dailymail.co.uk/femail/article-3540157/I-look-different-haven-t-changed-person-Transgender-woman-charts-20-year-transition-emotional-video-detailing-courage-come-out.html
# ['transgender', '_UNK', 'share', 'transition', 'journey', 'year']
# -----------------------
# 301.0
# http://www.msn.com/en-us/news/politics/exclusive-majority-of-americans-support-transgender-military-service/ar-AAoYTla
# ['majority', 'american', 'transgender', 'service']
# -----------------------
# 280.0
# https://www.wthr.com/article/trumps-transgender-troops-ban-divides-veterans-in-congress-0
# ['trump', 'transgender', 'troop', 'ban', 'veteran', 'congress']
# -----------------------
# 267.0
# http://www.nbcwashington.com/news/local/Police-Transgender-Inmate-Sexually-Assaulted-by-Maryland-Jail-Guard-434155933.html
# ['police', 'maryland', 'jail', 'guard', 'transgender', 'inmate']
# -----------------------
# 267.0
# http://www.cbsnews.com/videos/trump-administration-faces-fallout-from-transgender-military-ban/
# ['trump', 'administration', 'fallout', 'transgender', 'ban']
# -----------------------
# 258.0
# http://www.wthr.com/article/trumps-transgender-troops-ban-divides-veterans-in-congress-0
# ['trump', 'transgender', 'troop', 'ban', 'veteran', 'congress']
# -----------------------
# 245.0
# http://www.wsbtv.com/news/trending-now/what-is-the-difference-between-transgender-and-transsexual/572181753
# ['difference', 'transgender']
# -----------------------
# 233.0
# http://www.nola.com/military/index.ssf/2017/07/trump_to_bar_transgender_indiv.html
# ['trump', 'transgender', 'individual', 'force']
# -----------------------
# 227.0
# http://www.nola.com/military/index.ssf/2017/07/trump_to_bar_transgender_indiv.html#incart_most-comments
# ['trump', 'transgender', 'individual', 'force']
# -----------------------
# 215.0
# https://www.msn.com/en-us/news/politics/transgender-candidate-takes-on-culture-warrior-in-virginia/ar-AAoJ5Hr
# ['transgender', 'candidate', 'culture', 'warrior', 'virginia']
# -----------------------
# 213.0
# http://www.nola.com/military/index.ssf/2017/07/trump_to_bar_transgender_indiv.html#incart_river_home
# ['trump', 'transgender', 'individual', 'force']
# -----------------------
# 197.0
# https://a.msn.com/r/2/AAoTQ8J?m=en-us
# ['trump', 'transgender', 'troop', 'ban', 'veteran', 'congress']
# -----------------------
# 195.0
# http://www.msn.com/en-us/news/us/military-families-with-transgender-kids-fear-for-future/ar-AAoYANP
# ['family', 'transgender', 'kid']
# -----------------------
# 182.0
# http://www.dailymail.co.uk/tvshowbiz/article-3155113/Tyga-s-alleged-transgender-mistress-Mia-Isabella-responds-cheating-rumours-rapper-uses-music-fire-haters.html
# ['tyga', 'transgender', 'mistress', 'rumour']
# -----------------------
# 148.0
# http://www.cbsnews.com/videos/transgender-national-guardsman-speaks-out-on-trumps-ban/
# ['transgender', '_UNK', 'trump', 'ban']
# -----------------------
# 134.0
# http://www.ajc.com/news/local/cobb-pizza-restaurant-apologizes-for-facebook-transgender-posting/kwoom22hXkj1fhCOJdpKUK/
# ['cobb', 'pizza', 'restaurant', 'apologiz', 'facebook', 'transgender']
# -----------------------
# 129.0
# https://www.msn.com/en-us/news/politics/border-wall-tied-to-trump-transgender-ban-report/ar-AAoSxVS
# ['border', 'wall', 'transgender', 'ban', 'report']
# -----------------------
# 125.0
# https://www.msn.com/en-us/news/politics/why-the-transgender-troop-ban-may-backfire-politically/ar-AAoSD1a
# ['transgender', 'troop', 'ban']
# -----------------------
# 124.0
# http://www.cbsnews.com/news/defense-secretary-faces-pushback-on-lifting-transgender-ban/
# ['defense', 'secretary', 'transgender', 'ban']
# -----------------------
# 122.0
# http://www.nola.com/military/index.ssf/2017/07/trump_to_bar_transgender_indiv.html#incart_m-rpt-2
# ['trump', 'transgender', 'individual', 'force']
# -----------------------
# 121.0
# https://www.msn.com/en-us/news/us/transgender-womans-photo-with-texas-governor-goes-viral/ar-AAosyoY
# ['transgender', 'woman', 'photo', 'governor']
# -----------------------
# 119.0
# http://www.nydailynews.com/entertainment/stars-slam-trump-transgender-military-ban-article-1.3357826
# ['star', 'president', 'trump', 'transgender', 'ban']
# -----------------------
# 106.0
# http://www.nbcwashington.com/entertainment/entertainment-news/Transgender-Comedian-Patti-Harrison-Challenges-Trump-Military-Ban-Tonight-436893663.html
# ['transgender', 'comedian', 'challenge', 'ban', 'tonight']
# -----------------------
# 102.0
# https://www.usatoday.com/story/news/politics/2017/07/01/pentagon-delays-acceptance-transgender-recruits-and-officers/445127001/
# ['pentagon', 'delay', 'acceptance', 'transgender', 'recruit', 'officer']
# -----------------------
# 86.0
# http://www.nydailynews.com/news/politics/politicians-respond-donald-trump-transgender-military-ban-article-1.3358240
# ['politician', 'trump', 'transgender', 'military', 'ban']
# -----------------------
# 82.0
# http://www.nola.com/military/index.ssf/2017/07/trump_to_bar_transgender_indiv.html#comments
# ['trump', 'transgender', 'individual', 'force']
# -----------------------
# 82.0
# https://a.msn.com/r/2/AAoMoIH?m=en-us
# ['transgender', 'boxer', 'fight', 'acceptance']
# -----------------------
# 80.0
# http://www.wpxi.com/news/trending-now/what-is-the-difference-between-transgender-and-transsexual/572181707
# ['difference', 'transgender']
# -----------------------
# 80.0
# http://www.nbcnews.com/feature/nbc-out/transgender-service-members-discuss-military-life-post-ban-n612216
# ['transgender', 'service', 'member', 'life', 'post', 'ban']
# -----------------------
# 68.0
# http://www.nbcnews.com/feature/nbc-out/trump-bump-more-transgender-candidates-seek-public-office-n750601
# ['trump', 'transgender', 'candidate', 'office']
# -----------------------
# 65.0
# https://www.usatoday.com/story/news/nation/2015/08/25/military-transgender-ban-set-end-next-may/32345385/
# ['transgender', 'ban', 'set']
# -----------------------
# 59.0
# http://www.huffingtonpost.com/mia-violet/yes-youre-trans-enough-to_b_9318754.html
# ['tran', 'transgender']
# -----------------------
# 54873.0
# http://www.politico.com/story/2017/07/26/white-house-press-briefing-highlights-240993
# ['highlight', 'house', 'brief', 'press', 'transgender', 'ban']
# -----------------------
# 54312.0
# http://www.hollywoodreporter.com/news/caitlyn-jenner-speaks-trump-transgender-military-ban-1024461?utm_source=AOL&amp;utm_campaign=Syndication&amp;utm_medium=Caitlyn Jenner Calls Out Trump Over Transgender Military Ban
# ['caitlyn', 'jenner', 'trump', 'transgender', 'ban']
# -----------------------
# 37891.0
# http://dailymail.co.uk/news/article-4733142
# ['transgender', 'navy', 'seal', 'trump', 'ban']
# -----------------------
# 31190.0
# http://www.politico.com/story/2017/07/27/candidate-withdraws-dhs-post-transgender-ban-241053
# ['candidate', 'job', 'transgender', 'ban']
# -----------------------
# 28647.0
# http://dailymail.co.uk/news/article-4733356
# ['trump', 'reporter', '_UNK', 'transgender', 'ban']
# -----------------------
# 24916.0
# https://apnews.com/43d5866df5bb4a098edf7f496ae968d5
# ['trump', 'order', 'bar', 'transgender', 'troop']
# -----------------------
# 21785.0
# http://www.breitbart.com/tech/2017/07/26/tech-execs-attack-trump-over-transgender-military-ban/
# ['tech', 'exec', 'attack', 'trump', 'transgender', 'ban']
# -----------------------
# 19328.0
# http://www.cbsnews.com/news/troops-veterans-react-to-trumps-transgender-ban-in-military/
# ['troop', 'veteran', 'transgender', 'ban']
# -----------------------
# 16907.0
# http://www.politico.com/story/2017/07/26/transgender-military-ban-how-the-policy-could-impact-current-troops-240987
# ['trump', 'transgender', 'ban', 'policy']
# -----------------------
# 13651.0
# https://www.cnet.com/news/tech-leaders-lash-out-against-trumps-transgender-ban/
# ['tech', 'leader', 'trump', 'transgender', 'military', 'ban']
# -----------------------
# 12879.0
# http://bigstory.ap.org/urn:publicid:ap.org:43d5866df5bb4a098edf7f496ae968d5
# ['trump', 'order', 'bar', 'transgender', 'troop']
# -----------------------
# 8360.0
# http://www.faithfamilyamerica.com/teen_heartthrob_speaks_out_against_trump_on_transgender_rights
# ['teen', '_UNK', 'trump', 'transgender', 'right']
# -----------------------
# 7339.0
# http://www.dailymail.co.uk/news/article-4733142/Transgender-former-Navy-SEAL-slams-Trump-military-ban.html
# ['transgender', 'navy', 'seal', 'trump', 'ban']
# -----------------------
# 6819.0
# https://www.usatoday.com/story/news/nation/2013/06/04/seal-team-6-transgender-memoir-warrior-princess/2388431/
# ['navy', 'seal', 'secret', 'life', 'transgender']
# -----------------------
# 5671.0
# http://www.nbcnews.com/feature/nbc-out/thai-transgender-boxer-winning-fight-acceptance-n786311
# ['transgender', 'boxer', 'fight', 'acceptance']
# -----------------------
# 5294.0
# http://www.dailymail.co.uk/news/article-4732984/Caitlyn-Jenner-speaks-against-Trump-s-transgender-ban.html
# ['caitlyn', 'jenner', '_UNK', 'cox', 'trump', 'transgender', 'ban']
# -----------------------
# 5146.0
# https://www.bloomberg.com/news/articles/2017-07-27/pentagon-pushes-back-on-trump-bid-to-change-transgender-policy
# ['pentagon', 'trump', 'change', 'transgender', 'policy']
# -----------------------
# 4820.0
# https://www.usatoday.com/story/news/nation/2017/07/27/trump-transgender-military-ban-gay-ex-army-chief-eric-fanning-blasts-move/515699001/
# ['ex', 'army', 'chief', 'transgender', 'ban']
# -----------------------
# 3971.0
# http://mapi.huffpost.com/us/entry/us_597a2a7ee4b02a8434b4e29a
# ['pentagon', 'ban', 'transgender', 'troop']
# -----------------------
# 3801.0
# http://www.nydailynews.com/news/politics/transgender-veteran-sees-panic-unrest-trans-troops-article-1.3360880
# ['transgender', 'veteran', 'panic', 'unrest', 'troop']
# -----------------------
# 3391.0
# http://www.dailymail.co.uk/news/article-4735902/How-transgender-soldiers-REALLY-cost-military.html
# ['transgender', 'soldier']
# -----------------------
# 3370.0
# http://www.dailymail.co.uk/news/article-4733356/Trump-calls-reporter-rude-asking-trans-ban.html
# ['trump', 'reporter', '_UNK', 'transgender', 'ban']
# -----------------------
# 3278.0
# http://dailym.ai/2v8zL2u
# ['caitlyn', 'jenner', '_UNK', 'cox', 'trump', 'transgender', 'ban']
# -----------------------
# 3273.0
# https://www.usatoday.com/story/news/2017/07/26/transgender-service-members-doubt-trump-can-kick-them-out/513882001/
# ['transgender', 'service', 'member', 'doubt', 'trump']
# -----------------------
# 3231.0
# http://www.nbcnews.com/feature/nbc-out/military-families-transgender-kids-fear-future-n787046
# ['family', 'transgender', 'kid', 'future']
# -----------------------
# 3134.0
# http://www.10tv.com/article/trump-announces-ban-transgender-service-members-military
# ['trump', 'ban', 'transgender', 'service', 'member']
# -----------------------
# 2883.0
# http://dailym.ai/2v8zdcJ
# ['transgender', 'navy', 'seal', 'trump', 'ban']
# -----------------------
# 2821.0
# http://www.faithfamilyamerica.com/breaking_trump_tells_transgenders_you_can_t_serve_in_military
# ['trump', 'transgender']
# -----------------------
# 2784.0
# http://dailymail.co.uk/news/article-4735902
# ['transgender', 'soldier']
# -----------------------
# 2552.0
# https://www.usatoday.com/videos/news/politics/2017/07/27/trump-says-military-no-longer-accept-transgender-troops/104022050/
# ['trump', 'military', 'transgender', 'troop']
# -----------------------
# 2267.0
# http://www.cbsnews.com/videos/transgender-military-ban-met-with-protests-and-bipartisan-criticism/
# ['transgender', 'ban', 'protest', 'criticism']
# -----------------------
# 2164.0
# http://www.nbcnews.com/feature/nbc-out/transgender-texan-trolls-governor-protest-bathroom-bill-n783906
# ['transgender', 'texan', 'governor', 'bathroom', 'bill']
# -----------------------
# 1867.0
# http://www.huffingtonpost.com/entry/pentagon-transgender-troops-ban_us_597a2a7ee4b02a8434b4e29a
# ['pentagon', 'ban', 'transgender', 'troop']
# -----------------------
# 1807.0
# http://www.mirror.co.uk/news/uk-news/how-you-sex-youre-transgender-6188565
# ['sex', 'transgender']
# -----------------------
# 1474.0
# http://www.dailymail.co.uk/femail/article-4357700/Transgender-man-shares-revealing-images.html
# ['transgender', 'man', 'transition', 'image']
# -----------------------
# 1269.0
# http://www.10tv.com/article/trump-says-transgender-people-should-be-barred-military
# ['trump', 'transgender', 'people']
# -----------------------
# 1140.0
# https://www.bloomberg.com/news/articles/2017-07-27/tweets-before-policy-as-trump-bans-transgender-service-members
# ['tweet', 'policy', 'trump', 'transgender', 'service', 'member']
# -----------------------
# 1133.0
# https://www.usatoday.com/story/news/politics/onpolitics/2017/07/26/chelsea-manning-progressive-groups-slam-president-trumps-transgender-ban/512060001/
# ['chelsea', 'group', 'president', 'trump', 'transgender', 'ban']
# -----------------------
# 1104.0
# http://www.dailymail.co.uk/femail/article-2966581/Teenager-born-boy-wanted-girl-aged-THREE-reveals-struggles-finding-love.html
# ['transgender', 'teenager', 'dream', 'school', 'date']
# -----------------------
# 874.0
# http://www.nbcnews.com/feature/nbc-out/majority-americans-support-transgender-military-service-poll-finds-n787631
# ['majority', 'american', 'transgender', 'service', 'poll']
# -----------------------
# 872.0
# http://www.businessinsider.com/ap-the-latest-pentagon-not-aware-of-trump-transgender-decision-2017-7
# ['pentagon', 'trump', 'transgender', 'decision']
# -----------------------
# 853.0
# http://www.nbcwashington.com/news/politics/Top-US-Military-Officer-Transgender-Policy-Unchanged-for-Now---436982353.html
# ['officer', 'transgender', 'policy']
# -----------------------
# 802.0
# http://www.cbsnews.com/news/non-binary-transgender-you-havent-heard-of/
# ['type', 'transgender']
# -----------------------
# 730.0
# http://www.10tv.com/article/top-military-officer-says-transgender-policy-unchanged-now
# ['officer', 'transgender', 'policy']
# -----------------------
# 697.0
# https://a.msn.com/r/2/AAoYANP?m=en-us
# ['family', 'transgender', 'kid', 'future']
# -----------------------
# 652.0
# http://www.msn.com/en-us/news/us/transgender-service-members-doubt-trump-can-kick-them-out/ar-AAoSrBN
# ['transgender', 'service', 'member', 'doubt', 'trump']
# -----------------------
# 638.0
# https://apnews.com/9349c44d13d54cfab51ff5f5a71f5635
# ['lgbt', 'outrage', 'trump', 'ban', 'transgender', 'military', 'service']
# -----------------------
# 624.0
# http://www.10tv.com/article/lgbt-outrage-over-trump-ban-transgender-military-service
# ['lgbt', 'outrage', 'trump', 'ban', 'transgender', 'military', 'service']
# -----------------------
# 604.0
# http://www.independent.co.uk/arts-entertainment/tv/news/donald-trump-transgender-us-military-ban-caitlyn-jenner-laverne-cox-orange-is-the-new-black-a7862031.html
# ['caitlyn', 'jenner', 'transgender', 'ban']
# -----------------------
# 583.0
# http://www.cbsnews.com/videos/transgender-retired-navy-seal-kristen-beck-on-military-ban/
# ['transgender', 'navy', 'seal', 'kristen', '_UNK', 'ban']
# -----------------------
# 576.0
# http://www.cbsnews.com/news/trump-announces-ban-on-transgender-service-members-in-military-twitter/?ftag=CNM-00-10aab6a&linkId=40211842
# ['trump', 'ban', 'transgender', 'service', 'member']
# -----------------------
# 544.0
# http://articles.latimes.com/2014/jan/28/local/la-me-ln-suicide-attempts-alarming-transgender-20140127
# ['transgender', 'study', 'suicide', 'attempt', 'rate']
# -----------------------
# 527.0
# http://www.cleveland.com/darcy/index.ssf/2017/07/trump_on_mt_rushnmore_and_tran.html#incart_most-comments
# ['trump', 'mt', 'rushmore', 'transgender', 'ban', 'darcy', 'cartoon']
# -----------------------
# 501.0
# http://www.nydailynews.com/entertainment/gossip/kelly-speaks-daughter-coming-transgender-article-1.1843302
# ['r', 'daughter', 'transgender']
# -----------------------
# 469.0
# http://www.oregonlive.com/sports/index.ssf/2017/07/ray_allen_caitlyn_jenner_blast.html
# ['ray', 'allen', 'caitlyn', 'jenner', 'blast', 'donald', 'trump', 'transgender', 'ban']
# -----------------------
# 463.0
# https://www.usatoday.com/story/tech/2017/07/26/facebooks-zuckerberg-apples-cook-oppose-trumps-military-transgender-ban/479759001/
# ['zuckerberg', 'apple', 'cook', 'trump', 'transgender', 'ban']
# -----------------------
# 446.0
# http://bigstory.ap.org/urn:publicid:ap.org:9349c44d13d54cfab51ff5f5a71f5635
# ['lgbt', 'outrage', 'trump', 'ban', 'transgender', 'military', 'service']
# -----------------------
# 421.0
# http://dailym.ai/2vb3YOe
# ['transgender', 'soldier']
# -----------------------
# 385.0
# http://www.dailymail.co.uk/news/article-2992207/Transgender-teen-Jazz-Jennings-14-lived-girl-five-signs-star-TLC-reality-series-love-acceptance-support-family-friends.html
# ['transgender', 'teen', 'jazz', 'jenning', 'reality', 'series']
# -----------------------
# 379.0
# http://www.nola.com/national_politics/2017/07/transgender_troop_ban_congress.html
# ['donald', 'trump', 'transgender', 'troop', 'ban', 'veteran', 'congress']
# -----------------------
# 371.0
# http://www.cleveland.com/darcy/index.ssf/2017/07/trump_on_mt_rushnmore_and_tran.html#incart_river_home
# ['trump', 'mt', 'rushmore', 'transgender', 'ban', 'darcy', 'cartoon']
# -----------------------
# 350.0
# https://www.10tv.com/article/trump-announces-ban-transgender-service-members-military
# ['trump', 'ban', 'transgender', 'service', 'member']
# -----------------------
# 326.0
# http://www.cbsnews.com/news/trump-announces-ban-on-transgender-service-members-in-military-twitter/?ftag=CNM-00-10aab6a&linkId=40212470
# ['trump', 'ban', 'transgender', 'service', 'member']
# -----------------------
# 323.0
# http://www.oregonlive.com/sports/index.ssf/2017/07/ray_allen_caitlyn_jenner_blast.html#incart_river_home
# ['ray', 'allen', 'caitlyn', 'jenner', 'blast', 'donald', 'trump', 'transgender', 'ban']
# -----------------------
# 322.0
# http://www.dailymail.co.uk/news/article-2655163/R-Kellys-14-year-old-Jaya-comes-transgender-reveals-singer-spoken-announced-hes-boy.html
# ['r', 'child', 'transgender']
# -----------------------
# 283.0
# http://www.dailymail.co.uk/news/article-2800742/transgender-military-personnel-18-countries-open-service-allowed-gather-discuss-military-join.html
# ['transgender', 'military', 'personnel', 'country']
# -----------------------
# 254.0
# http://www.independent.co.uk/arts-entertainment/tv/news/stephen-colbert-trump-lgbt-transgender-military-ban-the-late-show-samantha-bee-full-frontal-daily-a7862361.html
# ['night', 'host', 'trump', 'transgender', 'ban']
# -----------------------
# 226.0
# http://www.ajc.com/news/lgbt-outrage-over-trump-ban-transgender-military-service/Zf6Q7rSgFCP2qbgLN1XMOK/
# ['lgbt', 'outrage', 'trump', 'ban', 'transgender', 'military', 'service']
# -----------------------
# 225.0
# https://a.msn.com/r/2/AAoSrBN?m=en-us
# ['transgender', 'service', 'member', 'doubt', 'trump']
# -----------------------
# 222.0
# https://apnews.com/0ef401443ff142e2a090be3da80f61a8
# ['maryland', 'man', 'killing', 'transgender', 'woman']
# -----------------------
# 217.0
# http://bigstory.ap.org/urn:publicid:ap.org:0ef401443ff142e2a090be3da80f61a8
# ['maryland', 'man', 'killing', 'transgender', 'woman']
# -----------------------
# 213.0
# http://www.nbcnews.com/feature/nbc-out/pentagon-lifts-ban-transgender-service-members-serving-openly-n601816
# ['pentagon', 'ban', 'transgender', 'service', 'member']
# -----------------------
# 186.0
# http://www.politico.com/states/new-jersey/story/2017/07/21/christie-signs-two-bills-to-protect-lgbt-members-113560
# ['christie', 'sign', 'bill', 'protection', 'transgender', 'student']
# -----------------------
# 185.0
# http://www.cbsnews.com/news/non-binary-transgender-you-havent-heard-of/?ftag=MSF0951a18
# ['type', 'transgender']
# -----------------------
# 184.0
# http://www.cleveland.com/darcy/index.ssf/2017/07/trump_on_mt_rushnmore_and_tran.html
# ['trump', 'mt', 'rushmore', 'transgender', 'ban', 'darcy', 'cartoon']
# -----------------------
# 181.0
# https://www.usatoday.com/story/news/politics/2017/01/18/chelsea-manning-lose-transgender-benefits-dishonorable-discharge/96742180/
# ['chelsea', 'transgender', 'benefit', '_UNK']
# -----------------------
# 167.0
# http://www.nola.com/national_politics/2017/07/transgender_troop_ban_congress.html#incart_river_home
# ['donald', 'trump', 'transgender', 'troop', 'ban', 'veteran', 'congress']
# -----------------------
# 164.0
# http://www.huffingtonpost.com/brynn-tannehill/johns-hopkins-professor-e_b_9510808.html
# ['johns', 'hopkin', 'professor', 'life', 'transgender', 'youth']
# -----------------------
# 162.0
# http://www.dailymail.co.uk/news/article-3061628/Transgender-teen-Leelah-Alcorn-s-death-officially-ruled-suicide-26-page-report-details-desperate-internet-searches-text-messages-leaped-semi-trailer-truck.html
# ['transgender', 'teen', '_UNK', 'death', 'suicide']
# -----------------------
# 157.0
# http://www.cbsnews.com/videos/trump-tweets-intention-to-ban-transgender-people-from-military/
# ['trump', 'tweet', '_UNK', 'transgender', 'people']
# -----------------------
# 146.0
# https://a.msn.com/r/2/AAoSGPK?m=en-us
# ['lady', 'trump', 'transgender', 'military', 'ban']
# -----------------------
# 142.0
# https://www.usatoday.com/story/news/politics/2016/06/24/ban-transgender-troops-lifted-july-1/86347902/
# ['ban', 'transgender', 'troop']
# -----------------------
# 142.0
# http://www.cbsnews.com/news/transgender-people-hope-for-acceptance-in-military-society/
# ['transgender', 'people', 'acceptance', 'military']
# -----------------------
# 137.0
# http://www.huffingtonpost.com/2015/02/12/kristin-beck_n_6673744.html
# ['transgender', 'navy', 'seal', '_UNK', 'hoyer']
# -----------------------
# 135.0
# http://www.dailymail.co.uk/femail/article-3491679/Transgender-man-born-girl-reveals-new-genitalia-Jeremy-Kyle.html
# ['transgender', 'man', '_UNK', 'jeremy', 'kyle']
# -----------------------
# 127.0
# http://www.usatoday.com/story/news/politics/2017/01/18/chelsea-manning-lose-transgender-benefits-dishonorable-discharge/96742180/
# ['chelsea', 'transgender', 'benefit', '_UNK']
# -----------------------
# 117.0
# http://www.huffingtonpost.com/entry/the-real-reason-republicans-keep-pushing-transgender_us_58b70c69e4b015675cf65b10
# ['reason', 'transgender', 'bathroom', 'ban']
# -----------------------
# 114.0
# http://www.cbsnews.com/news/troops-veterans-react-to-trumps-transgender-ban-in-military/?ftag=CNM-00-10aab6g&linkId=40260391
# ['troop', 'veteran', 'transgender', 'ban']
# -----------------------
# 112.0
# http://www.cbsnews.com/news/trump-announces-ban-on-transgender-service-members-in-military-twitter/?ftag=CNM-00-10aab6j&linkId=40212415
# ['trump', 'ban', 'transgender', 'service', 'member']
# -----------------------
# 105.0
# https://www.10tv.com/article/trump-says-transgender-people-should-be-barred-military
# ['trump', 'transgender', 'people']
# -----------------------
# 104.0
# http://www.cleveland.com/nation/index.ssf/2017/07/donald_trump_to_bar_transgende.html#incart_river_home
# ['donald', 'trump', 'transgender', 'individual', 'force']
# -----------------------
# 101.0
# http://bigstory.ap.org/9349c44d13d54cfab51ff5f5a71f5635
# ['lgbt', 'outrage', 'trump', 'ban', 'transgender', 'military', 'service']
# -----------------------
# 100.0
# http://www.cbsnews.com/news/trump-announces-ban-on-transgender-service-members-in-military-twitter/?ftag=YHF4eb9d17&yptr=yahoo
# ['trump', 'ban', 'transgender', 'service', 'member']
# -----------------------
# 96.0
# http://www.cbsnews.com/videos/eye-opener-at-8-transgender-military-ban-triggers-protests/
# ['eye', 'opener', 'transgender', 'military', 'ban', 'protest']
# -----------------------
# 96.0
# http://www.nola.com/national_politics/2017/07/transgender_troop_ban_congress.html#incart_m-rpt-2
# ['donald', 'trump', 'transgender', 'troop', 'ban', 'veteran', 'congress']
# -----------------------
# 90.0
# http://www.pennlive.com/midstate/index.ssf/2015/03/how_to_talk_to_a_transgender_p.html
# ['transgender', 'question']
# -----------------------
# 83.0
# http://www.nola.com/national_politics/2017/07/transgender_troop_ban_congress.html#incart_river_home_pop
# ['donald', 'trump', 'transgender', 'troop', 'ban', 'veteran', 'congress']
# -----------------------
# 81.0
# http://www.ajc.com/news/national/photo-texas-gov-alongside-transgender-woman-goes-viral/rlcP1FJEseC4zpRaSQiZGK/
# ['photo', 'gov', 'transgender', 'woman']
# -----------------------
# 78.0
# http://www.cleveland.com/nation/index.ssf/2017/07/donald_trump_to_bar_transgende.html
# ['donald', 'trump', 'transgender', 'individual', 'force']
# -----------------------
# 77.0
# http://www.nbcwashington.com/multimedia/Tonight-Show-Monologue-Trump-Military-Transgender-Ban-436896993.html
# ['tonight', 'fallon', 'transgender', 'comedian', 'talk', 'trump', 'military', 'ban']
# -----------------------
# 75.0
# http://www.oregonlive.com/sports/index.ssf/2017/07/ray_allen_caitlyn_jenner_blast.html#incart_river_index
# ['ray', 'allen', 'caitlyn', 'jenner', 'blast', 'donald', 'trump', 'transgender', 'ban']
# -----------------------
# 71.0
# http://www.cleveland.com/darcy/index.ssf/2017/07/trump_on_mt_rushnmore_and_tran.html#incart_river_index
# ['trump', 'mt', 'rushmore', 'transgender', 'ban', 'darcy', 'cartoon']
# -----------------------
# 65.0
# http://www.dailymail.co.uk/news/article-3277598/Man-20-arrested-shooting-alley-murder-21-year-old-transgender-woman-suffered-multiple-gunshot-wounds.html
# ['man', 'alley', 'murder', 'transgender', 'woman']
# -----------------------
# 64.0
# http://bigstory.ap.org/urn:publicid:ap.org:99f591daf77a4bbb8db0ea4e880e3c43
# ['britain', 'tape', 'transgender', 'people']
# -----------------------
# 61.0
# http://www.dailymail.co.uk/femail/article-3173639/I-m-praying-hasn-t-surgery-Caroline-Cossey-Playboy-s-transgender-model-issues-stark-warning-Caitlyn-Jenner-rushing-transition.html
# ['playboy', 'transgender', 'model', 'issue', 'jenner']
# -----------------------
# 59.0
# http://www.cbsnews.com/news/trump-announces-ban-on-transgender-service-members-in-military-twitter/#comments
# ['trump', 'ban', 'transgender', 'service', 'member']
# -----------------------
# 55.0
# http://www.nbcnews.com/feature/nbc-out/minnesota-mom-sues-her-trans-child-over-gender-reassignment-n685266
# ['minnesota', 'mom', 'transgender', 'child', 'gender', 'reassignment']
# -----------------------
# 186292.0
# https://www.thefiscaltimes.com/2017/07/26/How-Much-Do-Transgender-Soldiers-Really-Cost-US-Military
# ['transgender', 'soldier']
# -----------------------
# 79440.0
# http://www.breitbart.com/big-government/2017/07/26/trump-announces-ban-on-transgender-people-in-the-u-s-military/
# ['trump', 'ban', 'transgender', 'u']
# -----------------------
# 48455.0
# http://www.breitbart.com/big-government/2017/07/27/delingpole-trumps-transgender-military-ban-is-the-best-thing-ever/
# ['_UNK', 'trump', 'transgender', 'military', 'ban', 'thing']
# -----------------------
# 47836.0
# http://www.breitbart.com/big-government/2017/07/26/john-mccain-backs-transgender-ideology-slams-donald-trumps-policy/
# ['john', 'mccain', 'transgender', '_UNK', 'donald', 'trump', 'policy']
# -----------------------
# 39850.0
# http://www.breitbart.com/big-government/2017/07/27/james-woods-transgender-claims-serious-harm-youths/
# ['jame', 'wood', 'transgender', 'claim', 'harm', 'youth']
# -----------------------
# 33706.0
# http://www.msnbc.com/rachel-maddow-show/white-house-struggles-defend-trumps-ban-transgender-troops
# ['house', 'trump', 'ban', 'transgender', 'troop']
# -----------------------
# 33511.0
# http://www.nbcnews.com/feature/nbc-out/trump-s-tweets-may-leave-transgender-service-members-harm-s-n786721
# ['trump', 'tweet', 'transgender', 'service', 'member', 'harm', 'way']
# -----------------------
# 21972.0
# http://www.msnbc.com/stephanie-ruhle/watch/joint-chiefs-no-change-in-transgender-policy-until-wh-clarifies-1011356739689
# ['chief', 'change', 'transgender', 'policy']
# -----------------------
# 21153.0
# https://a.msn.com/r/2/AAoRJm5?m=en-us
# ['world', 'lgbtq', 'community', 'trump', 'transgender', 'military', 'ban']
# -----------------------
# 19882.0
# http://www.cbsnews.com/news/political-world-lgbtq-community-react-to-trump-transgender-military-ban/
# ['world', 'lgbtq', 'community', 'trump', 'transgender', 'military', 'ban']
# -----------------------
# 19026.0
# http://www.breitbart.com/sports/2017/07/27/nbas-ray-allen-says-jesus-opposes-president-trumps-transgender-ban/
# ['nba', 'ray', 'allen', 'jesus', 'president', 'trump', 'transgender', 'ban']
# -----------------------
# 13796.0
# http://www.cbsnews.com/news/trump-transgender-ban-service-members-costs/
# ['trump', 'transgender', 'soldier']
# -----------------------
# 13483.0
# https://a.msn.com/r/2/AAoVzYB?m=en-us
# ['trump', 'progress', 'tweet', 'transgender', 'veteran']
# -----------------------
# 13476.0
# http://www.cbsnews.com/news/ex-navy-sailor-gets-40-years-for-killing-transgender-woman/
# ['navy', 'sailor', 'year', 'transgender', 'woman']
# -----------------------
# 11636.0
# http://www.cbsnews.com/news/ex-navy-sailor-gets-40-years-for-killing-transgender-woman/?ftag=COS-05-10aaa0h&utm_campaign=trueAnthem: Trending Content&utm_content=5972dc4a04d3012eba16bd7c&utm_medium=trueAnthem&utm_source=facebook
# ['navy', 'sailor', 'year', 'transgender', 'woman']
# -----------------------
# 11505.0
# http://www.businessinsider.com/transgendered-seal-team-6er-issues-scathing-response-to-chelsea-manning-2013-8
# ['transgender', 'seal', 'team', 'issue', 'response', 'chelsea']
# -----------------------
# 9727.0
# http://www.nbcnews.com/feature/nbc-out/queen-sugar-actor-brian-michael-smith-comes-out-transgender-n783451
# ['queen', 'sugar', 'actor', 'brian', 'michael', 'smith', 'transgender']
# -----------------------
# 8947.0
# https://www.usatoday.com/videos/news/politics/2017/07/27/ivanka-trump-faces-backlash-tweet-after-transgender-military-ban/104037584/
# ['ivanka', 'trump', 'backlash', 'tweet', 'transgender', 'military', 'ban']
# -----------------------
# 8683.0
# http://www.politico.com/story/2017/07/20/house-republicans-try-to-revive-ban-on-transgender-pentagon-surgeries-240770
# ['house', 'republican', 'ban', 'pentagon', 'transgender', 'surgery']
# -----------------------
# 8530.0
# http://www.businessinsider.com/mark-zuckerberg-trump-facebook-transgender-military-ban-2017-7
# ['facebook', 'ceo', 'mark', 'zuckerberg', 'trump', 'transgender', 'military', 'ban']
# -----------------------
# 5380.0
# http://www.ajc.com/news/breaking-news/trump-transgender-people-won-allowed-the-military/QWgirDIX79wWFe9t5uNloJ/
# ['trump', 'transgender', 'people', 'military']
# -----------------------
# 5363.0
# http://www.faithfamilyamerica.com/this_state_urged_schools_to_segregate_students_who_are_uncomfortable_with_transgender_bathrooms
# ['school', 'student', 'transgender', 'bathroom']
# -----------------------
# 5155.0
# http://dailymail.co.uk/news/article-4736530
# ['trump', 'military', 'transgender', 'ban', 'chaos', 'chief']
# -----------------------
# 5107.0
# http://www.nbcnews.com/feature/nbc-out/trump-transgender-ban-nod-christian-conservatives-n787026
# ['trump', 'military', 'transgender', 'ban', 'nod', 'conservative']
# -----------------------
# 4816.0
# http://www.independent.co.uk/news/world/americas/man-stab-woman-119-times-transgender-told-date-mississippi-hotel-room-dwayne-hickerson-dee-whigham-a7860591.html
# ['man', 'woman', 'time', 'transgender']
# -----------------------
# 4730.0
# http://mashable.com/2017/07/26/caitlyn-jenner-responds-to-trumps-transgender-military-ban/
# ['caitlyn', 'jenner', 'silence', 'trump', 'transgender', 'military', 'ban']
# -----------------------
# 3812.0
# http://dailymail.co.uk/news/article-4716346
# ['navy', 'sailor', 'year', 'transgender', 'woman']
# -----------------------
# 3589.0
# http://www.huffingtonpost.com/entry/what-its-like-to-be-transgender-in-the-armed-forces_us_597a3260e4b06b305561ced1
# ['transgender', 'force']
# -----------------------
# 3579.0
# http://www.breitbart.com/tech/2017/07/24/uc-berkeley-adds-new-healthcare-benefits-for-transgender-students/
# ['berkeley', 'healthcare', 'benefit', 'transgender', 'student']
# -----------------------
# 3375.0
# http://www.cbsnews.com/news/ex-navy-sailor-gets-40-years-for-killing-transgender-woman/?ftag=CNM-00-10aab5i&linkId=40041133
# ['navy', 'sailor', 'year', 'transgender', 'woman']
# -----------------------
# 3217.0
# http://www.wpxi.com/news/top-stories/joint-chiefs-chair-no-change-to-transgender-policy-in-military/573287684
# ['chief', 'chair', 'change', 'transgender', 'policy']
# -----------------------
# 2989.0
# http://www.nbcnews.com/feature/nbc-out/gov-christie-oks-law-give-schools-transgender-policy-guidance-n785961
# ['gov', 'christie', 'law', 'school', 'transgender', 'policy', 'guidance']
# -----------------------
# 2425.0
# http://mapi.huffpost.com/us/entry/us_59791ad0e4b02a8434b3a093
# ['world', 'leader', 'trump', 'transgender', 'military', 'ban']
# -----------------------
# 2332.0
# http://www.cbsnews.com/news/ex-navy-sailor-gets-40-years-for-killing-transgender-woman/?ftag=COS-05-10aaa0h&utm_campaign=trueAnthem: Trending Content&utm_content=5973436904d3011d49aa33f0&utm_medium=trueAnthem&utm_source=facebook
# ['navy', 'sailor', 'year', 'transgender', 'woman']
# -----------------------
# 2017.0
# http://www.dailymail.co.uk/news/article-4716346/Navy-seaman-training-admits-killing-transgender-woman.html
# ['navy', 'sailor', 'year', 'transgender', 'woman']
# -----------------------
# 1986.0
# http://www.10tv.com/article/ex-navy-sailor-gets-40-years-killing-transgender-woman
# ['navy', 'sailor', 'year', 'transgender', 'woman']
# -----------------------
# 1888.0
# http://www.oregonlive.com/transgender-health/2017/07/about_a_boy_jays_life_as_a_tra.html#incart_big-photo
# ['boy', 'transgender', 'teen', 'tipping', 'point']
# -----------------------
# 1668.0
# http://www.huffingtonpost.com/entry/world-leaders-react-trump-transgender-military_us_59791ad0e4b02a8434b3a093
# ['world', 'leader', 'trump', 'transgender', 'military', 'ban']
# -----------------------
# 1631.0
# http://mashable.com/2017/07/26/trump-transgender-military-ban-viagra-costs-more/
# ['viagra', 'time', 'transgender', 'service']
# -----------------------
# 1582.0
# http://www.msn.com/en-us/news/politics/political-world-lgbtq-community-react-to-trump-transgender-military-ban/ar-AAoRJm5
# ['world', 'lgbtq', 'community', 'trump', 'transgender', 'military', 'ban']
# -----------------------
# found total 293 relevant titles

# %%
plt.hist(counter.values(), bins=100)
#plt.yscale('log')
axes = plt.gca()
axes.set_xlim([0,20])
#axes.set_ylim([ymin,ymax])

# %%
data_path = '/Users/matt.meng/Downloads'
file_name = 'small_articles.json'

# %%
#bad_titles

# %%
pickle_file = 'processed_title_data.pkl'

content = {'url' : selected_title_urls, 
           'titles' : titles, 
           'pageViw' : selected_title_pageView,
           'token_dict' : token_dict,
           'reverse_token_dict' : reverse_token_dict}

with open(pickle_file, 'wb') as handle:
    cPickle.dump(content, handle, protocol=cPickle.HIGHEST_PROTOCOL)
