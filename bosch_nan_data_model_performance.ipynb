# %%
import pandas as pd
import numpy as np
import yaml
import sys, os, time
from os.path import join

# %%
def extract_xgb_model_feature_importances(data_path_list, file_name):
    xgb_row_list = []
    for data_path in data_path_list:
        grid_search_dict = yaml.load(open(join(data_path, file_name), 'r'))
        for elem in grid_search_dict.values():
            #print 'before appending:', row_list
            tmp_dict = elem['model_params']
            tmp_dict['model_threshold'] = elem['model_threshold']
            tmp_dict['model_type'] = elem['model_type']
            tmp_dict['result'] = elem['result']
            xgb_row_list.append(tmp_dict.copy())
            
    xgb_fea_imp_df = pd.DataFrame(xgb_row_list)
    print xgb_fea_imp_df.shape
    return xgb_fea_imp_df

# %% [markdown]
# ## xgboost model using nan data

# %% [markdown]
#     1. combine xgboot model results from different sources
#         a. base_score implementation
#         b. grid search
#         c. potentially the base_score + pos_scale_weight

# %%
grid_search_data_path_0 = '/mnt/home/ymm/kaggle/bosch/data_nan_cross_fit_xgb_models/data_bin_nan_xgb_models_0'
grid_search_data_path_1 = '/mnt/home/ymm/kaggle/bosch/data_nan_cross_fit_xgb_models/data_bin_nan_xgb_models_1'
grid_search_data_path_2 = '/mnt/home/ymm/kaggle/bosch/data_nan_cross_fit_xgb_models/data_bin_nan_base_score_5000_trees_models'
grid_search_data_path_3 = '/mnt/home/ymm/kaggle/bosch/data_nan_cross_fit_xgb_models/data_bin_nan_base_score_7000_trees_models'
file_name = 'trained_combined_model.yml'
#grid_search_file_name = 'tmp.yml'

# %%
grid_search_data_path_list = [grid_search_data_path_0, grid_search_data_path_1, 
                              grid_search_data_path_2, grid_search_data_path_3]

# %%
xgb_fea_imp_df = extract_xgb_model_feature_importances(grid_search_data_path_list, file_name)
# Out:
# (22, 15)

# %%
xgb_fea_imp_df.groupby(['max_depth', 'num_round'])['result'].count()
# Out:
# max_depth  num_round
# 5          2500         10
#            5000          6
#            7000          6
# Name: result, dtype: int64

# %%
xgb_fea_imp_df.groupby(['max_depth', 'num_round'])['result'].mean()
# Out:
# max_depth  num_round
# 5          2500         0.335218
#            5000         0.349114
#            7000         0.342594
# Name: result, dtype: float64

# %%
xgb_fea_imp_df.groupby(['max_depth', 'num_round'])['result'].std()
# Out:
# max_depth  num_round
# 5          2500         0.023553
#            5000         0.019337
#            7000         0.009805
# Name: result, dtype: float64

# %%
xgb_fea_imp_df.sort(['result'], ascending=False)
# Out:
# /mnt/home/ymm/.virtualenvs/kaggle/lib/python2.7/site-packages/ipykernel/__main__.py:1: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   if __name__ == '__main__':
#     colsample_bytree     eta eval_metric  gamma  max_depth metrics  \
# 13               0.8  0.0075         auc      0          5     auc
# 12               0.8  0.0075         auc      0          5     auc
# 4                0.8  0.0075         auc      0          5     auc
# 8                0.8  0.0075         auc      0          5     auc
# 9                0.8  0.0075         auc      0          5     auc
# 20               0.8  0.0075         auc      0          5     auc
# 17               0.8  0.0075         auc      0          5     auc
# 11               0.8  0.0075         auc      0          5     auc
# 21               0.8  0.0075         auc      0          5     auc
# 19               0.8  0.0075         auc      0          5     auc
# 14               0.8  0.0075         auc      0          5     auc
# 0                0.8  0.0075         auc      0          5     auc
# 7                0.8  0.0075         auc      0          5     auc
# 2                0.8  0.0075         auc      0          5     auc
# 18               0.8  0.0075         auc      0          5     auc
# 15               0.8  0.0075         auc      0          5     auc
# 16               0.8  0.0075         auc      0          5     auc
# 10               0.8  0.0075         auc      0          5     auc
# 6                0.8  0.0075         auc      0          5     auc
# 5                0.8  0.0075         auc      0          5     auc
# 1                0.8  0.0075         auc      0          5     auc
# 3                0.8  0.0075         auc      0          5     auc
#
#     model_threshold model_type  num_round    result  seed  subsample  \
# 13         0.249752    Xgboost       5000  0.374699     0        0.8
# 12         0.299778    Xgboost       5000  0.368674    50        0.8
# 4          0.284914    Xgboost       2500  0.367784     0        0.8
# 8          0.197275    Xgboost       2500  0.364827    50        0.8
# 9          0.217959    Xgboost       2500  0.357983    50        0.8
# 20         0.175977    Xgboost       7000  0.353594    50        0.8
# 17         0.198388    Xgboost       7000  0.351478     0        0.8
# 11         0.237940    Xgboost       5000  0.350673     0        0.8
# 21         0.152465    Xgboost       7000  0.346470    50        0.8
# 19         0.327798    Xgboost       7000  0.341657     0        0.8
# 14         0.289084    Xgboost       5000  0.341645    50        0.8
# 0          0.158739    Xgboost       2500  0.336977     0        0.8
# 7          0.205756    Xgboost       2500  0.336473     0        0.8
# 2          0.198463    Xgboost       2500  0.334124    50        0.8
# 18         0.278654    Xgboost       7000  0.332674    50        0.8
# 15         0.366911    Xgboost       5000  0.330962    50        0.8
# 16         0.125131    Xgboost       7000  0.329691     0        0.8
# 10         0.301983    Xgboost       5000  0.328029     0        0.8
# 6          0.401988    Xgboost       2500  0.326224    50        0.8
# 5          0.233525    Xgboost       2500  0.321612     0        0.8
# 1          0.875148    Xgboost       2500  0.313099     0        0.8
# 3          0.758020    Xgboost       2500  0.293076    50        0.8
#
#    use_base_score    val  verbose_eval
# 13           True  False         100.0
# 12           True  False         100.0
# 4            True  False           NaN
# 8            True  False           NaN
# 9            True  False           NaN
# 20           True  False         100.0
# 17           True  False         100.0
# 11           True  False         100.0
# 21           True  False         100.0
# 19           True  False         100.0
# 14           True  False         100.0
# 0             NaN  False           NaN
# 7            True  False           NaN
# 2             NaN  False           NaN
# 18           True  False         100.0
# 15           True  False         100.0
# 16           True  False         100.0
# 10           True  False         100.0
# 6            True  False           NaN
# 5            True  False           NaN
# 1             NaN  False           NaN
# 3             NaN  False           NaN

# %%
xgb_fea_imp_df.sort(['max_depth', 'num_round'], ascending=False)

# %%
'''
grid_search_dict_0 = yaml.load(open(join(grid_search_data_path_0, file_name), 'r'))
grid_search_dict_1 = yaml.load(open(join(grid_search_data_path_1, file_name), 'r'))
grid_search_dict_2 = yaml.load(open(join(grid_search_data_path_2, file_name), 'r'))
grid_search_dict_3 = yaml.load(open(join(grid_search_data_path_3, file_name), 'r'))

xgb_row_list = []

for elem in base_score_dict.values():
    #print 'before appending:', row_list
    tmp_dict = elem['model_params']
    tmp_dict['model_threshold'] = elem['model_threshold']
    tmp_dict['model_type'] = elem['model_type']
    tmp_dict['result'] = elem['result']
    xgb_row_list.append(tmp_dict.copy())

for elem in grid_search_dict_0.values():
    #print 'before appending:', row_list
    tmp_dict = elem['model_params']
    tmp_dict['model_threshold'] = elem['model_threshold']
    tmp_dict['model_type'] = elem['model_type']
    tmp_dict['result'] = elem['result']
    xgb_row_list.append(tmp_dict.copy())
    
      
for elem in grid_search_dict_1.values():
    tmp_dict = elem['model_params']
    tmp_dict['model_threshold'] = elem['model_threshold']
    tmp_dict['model_type'] = elem['model_type']
    tmp_dict['result'] = elem['result']
    xgb_row_list.append(tmp_dict.copy())

    
for elem in grid_search_dict_2.values():
    tmp_dict = elem['model_params']
    tmp_dict['model_threshold'] = elem['model_threshold']
    tmp_dict['model_type'] = elem['model_type']
    tmp_dict['result'] = elem['result']
    xgb_row_list.append(tmp_dict.copy())
    
    
for elem in grid_search_FE_dict_0.values():
    tmp_dict = elem['model_params']
    tmp_dict['model_threshold'] = elem['model_threshold']
    tmp_dict['model_type'] = elem['model_type']
    tmp_dict['result'] = elem['result']
    xgb_row_list.append(tmp_dict.copy())
    
xgb_df = pd.DataFrame(xgb_row_list)
'''
# Out:
# "\ngrid_search_dict_0 = yaml.load(open(join(grid_search_data_path_0, file_name), 'r'))\ngrid_search_dict_1 = yaml.load(open(join(grid_search_data_path_1, file_name), 'r'))\ngrid_search_dict_2 = yaml.load(open(join(grid_search_data_path_2, file_name), 'r'))\ngrid_search_dict_3 = yaml.load(open(join(grid_search_data_path_3, file_name), 'r'))\n\nxgb_row_list = []\n\nfor elem in base_score_dict.values():\n    #print 'before appending:', row_list\n    tmp_dict = elem['model_params']\n    tmp_dict['model_threshold'] = elem['model_threshold']\n    tmp_dict['model_type'] = elem['model_type']\n    tmp_dict['result'] = elem['result']\n    xgb_row_list.append(tmp_dict.copy())\n\nfor elem in grid_search_dict_0.values():\n    #print 'before appending:', row_list\n    tmp_dict = elem['model_params']\n    tmp_dict['model_threshold'] = elem['model_threshold']\n    tmp_dict['model_type'] = elem['model_type']\n    tmp_dict['result'] = elem['result']\n    xgb_row_list.append(tmp_dict.copy())\n    \n      \nfor elem in grid_search_dict_1.values():\n    tmp_dict = elem['model_params']\n    tmp_dict['model_threshold'] = elem['model_threshold']\n    tmp_dict['model_type'] = elem['model_type']\n    tmp_dict['result'] = elem['result']\n    xgb_row_list.append(tmp_dict.copy())\n\n    \nfor elem in grid_search_dict_2.values():\n    tmp_dict = elem['model_params']\n    tmp_dict['model_threshold'] = elem['model_threshold']\n    tmp_dict['model_type'] = elem['model_type']\n    tmp_dict['result'] = elem['result']\n    xgb_row_list.append(tmp_dict.copy())\n    \n    \nfor elem in grid_search_FE_dict_0.values():\n    tmp_dict = elem['model_params']\n    tmp_dict['model_threshold'] = elem['model_threshold']\n    tmp_dict['model_type'] = elem['model_type']\n    tmp_dict['result'] = elem['result']\n    xgb_row_list.append(tmp_dict.copy())\n    \nxgb_df = pd.DataFrame(xgb_row_list)\n"
